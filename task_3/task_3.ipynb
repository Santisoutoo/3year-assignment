# %% [markdown]
# # Task III: Implementing GANs and Diffusion Model for Handwritten Character Generation using EMNIST Dataset
#
#
# <p align="center">
#   Santiago Souto Ortega,
#   Víctor Vega Sobral
# </p>

# %% [markdown]
# ![Instructions](instructions.png)

# %% [markdown]
# ---

# %% [markdown]
# ## Importing neccesary libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import torchvision.utils as vutils

# %% [markdown]
# ---

# %% [markdown]
# # 1. GAN Code

# %% [markdown]
# ## 1.1 Loading EMNIST

# %%
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

# Check if CUDA is available, otherwise use CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Define transformations
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))  # Normalize between -1 and 1
])

# %%
# Load EMNIST dataset (letters)
# EMNIST dataset contains handwritten characters (letters and digits)
# We're using the 'letters' split which contains 26 classes (A-Z)
try:
    train_dataset = datasets.EMNIST(
        root='./data',
        split='letters',  # Using letters for character generation
        train=True,
        download=True,
        transform=transform
    )
    
    # Create a DataLoader for batching and shuffling
    batch_size = 64
    train_loader = DataLoader(
        train_dataset, 
        batch_size=batch_size,
        shuffle=True,
        num_workers=2
    )
    
    print(f"Dataset loaded: {len(train_dataset)} training samples")
    print(f"Number of batches: {len(train_loader)}")
    
except Exception as e:
    print(f"Error loading dataset: {e}")
    print("If you're having issues, you might need to install additional libraries or check your internet connection")
# Out:
# Dataset loaded: 124800 training samples
# Number of batches: 1950

# %% [markdown]
# ## 1.2 Visualizing some sample images

# %%
def show_samples(dataloader, num_samples=25):
    """Display a grid of sample images from the dataset"""
    # Get a batch of images
    real_batch = next(iter(dataloader))
    real_images = real_batch[0][:num_samples].to(device)
    
    # Create a grid of images and display
    plt.figure(figsize=(8, 8))
    plt.axis("off")
    plt.title("Training Images")
    plt.imshow(
        np.transpose(
            vutils.make_grid(real_images.cpu(), padding=2, normalize=True).numpy(),
            (1, 2, 0)
        ),
        cmap='gray'
    )
    plt.show()

# %%
# Show some sample images
show_samples(train_loader)

# %% [markdown]
# # 1.3 Define the Generator network

# %%
class Generator(nn.Module):
    def __init__(self, latent_dim=100, img_size=28):
        super(Generator, self).__init__()
        
        # Calculate the size after convolutions
        self.img_size = img_size
        self.latent_dim = latent_dim
        
        # Initial size before upsampling: 7x7
        self.init_size = self.img_size // 4
        
        # First layer, processes the latent vector into a small convolutional map
        self.l1 = nn.Sequential(
            nn.Linear(latent_dim, 256 * self.init_size * self.init_size)  # Increased from 128 to 256
        )
        
        # Upsampling layers with more filters and additional layers
        self.conv_blocks = nn.Sequential(
            nn.BatchNorm2d(256),
            
            # First upsampling stage: 7x7 -> 14x14
            nn.Upsample(scale_factor=2),
            nn.Conv2d(256, 256, 3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),
            
            # Residual layer for improved gradient flow
            nn.Conv2d(256, 256, 3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),
            
            # Second upsampling stage: 14x14 -> 28x28
            nn.Upsample(scale_factor=2),
            nn.Conv2d(256, 128, 3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),
            
            # Additional layer for fine details
            nn.Conv2d(128, 64, 3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2, inplace=True),
            
            # Final layer for the output image
            nn.Conv2d(64, 1, 3, stride=1, padding=1),
            nn.Tanh()  # Output range: [-1, 1]
        )

    def forward(self, z):
        # Process the latent vector
        out = self.l1(z)
        # Reshape to match the dimensions expected by the convolutional layer
        out = out.view(out.shape[0], 256, self.init_size, self.init_size)
        # Apply convolutional blocks
        img = self.conv_blocks(out)
        return img

# %% [markdown]
# ## 1.4 Define the Discriminator network

# %%
class Discriminator(nn.Module):
    def __init__(self, img_size=28):
        super(Discriminator, self).__init__()
        
        self.img_size = img_size
        
        # Convolutional layers with consistent kernel_size
        self.model = nn.Sequential(
            # First layer
            nn.Conv2d(1, 64, 3, stride=2, padding=1),  # 28x28 -> 14x14
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout2d(0.2),
            
            # Second layer
            nn.Conv2d(64, 128, 3, stride=2, padding=1),  # 14x14 -> 7x7
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout2d(0.2),
            
            # Third layer
            nn.Conv2d(128, 256, 3, stride=2, padding=1),  # 7x7 -> 4x4 (or 3x3 depending on the padding)
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout2d(0.2),
        )
        
        # Variable to store if we have verified the dimensions
        self.initialized = False
        
        # The classification layer will be initialized on the first forward pass
        self.adv_layer = None
        
    def forward(self, img):
        # Apply convolutional feature extraction
        features = self.model(img)
        
        # Flatten the features
        features_flat = features.view(features.shape[0], -1)
        
        # First pass: initialize the linear layer with the correct dimensions
        if not self.initialized:
            input_size = features_flat.shape[1]
            self.adv_layer = nn.Sequential(
                nn.Linear(input_size, 512),
                nn.LeakyReLU(0.2, inplace=True),
                nn.Dropout(0.3),
                nn.Linear(512, 1),
                nn.Sigmoid()
            ).to(img.device)
            
            print(f"Initializing Discriminator linear layer with input size: {input_size}")
            self.initialized = True
        
        # Get the probability
        validity = self.adv_layer(features_flat)
        return validity

# %% [markdown]
# ## 1.5 Initialize models and define hyperparameters

# %%
# Hyperparameters
latent_dim = 100  # We keep the same latent space dimensionality
lr_g = 0.0001  # Reduced learning rate for the generator
lr_d = 0.0002  # Learning rate for the discriminator
beta1 = 0.5  # Beta1 parameter for the Adam optimizer
beta2 = 0.999  # Beta2 parameter for the Adam optimizer
num_epochs = 50  # Number of training epochs
label_smoothing = 0.9  # Smoothed labels for real images (instead of 1.0)

# Initialize generator and discriminator
generator = Generator(latent_dim=latent_dim).to(device)
discriminator = Discriminator().to(device)

# Print the architectures of the models
print("Generator Architecture:")
print(generator)
print("\nDiscriminator Architecture:")
print(discriminator)

# Loss function
adversarial_loss = nn.BCELoss()

# Optimizers with adjusted learning rates
optimizer_G = optim.Adam(generator.parameters(), lr=lr_g, betas=(beta1, beta2))
optimizer_D = optim.Adam(discriminator.parameters(), lr=lr_d, betas=(beta1, beta2))
# Out:
# Generator Architecture:
# Generator(
#   (l1): Sequential(
#     (0): Linear(in_features=100, out_features=12544, bias=True)
#   )
#   (conv_blocks): Sequential(
#     (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): Upsample(scale_factor=2.0, mode='nearest')
#     (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Upsample(scale_factor=2.0, mode='nearest')
#     (9): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): LeakyReLU(negative_slope=0.2, inplace=True)
#     (12): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): LeakyReLU(negative_slope=0.2, inplace=True)
#     (15): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): Tanh()
#   )
# )
#
# Discriminator Architecture:
# Discriminator(
#   (model): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Dropout2d(p=0.2, inplace=False)
#     (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): LeakyReLU(negative_slope=0.2, inplace=True)
#     (6): Dropout2d(p=0.2, inplace=False)
#     (7): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): LeakyReLU(negative_slope=0.2, inplace=True)
#     (10): Dropout2d(p=0.2, inplace=False)
#   )
# )

# %% [markdown]
# ## 1.6 Training Loop

# %%
# Lists to store training progress
G_losses = []
D_losses = []
generated_images = []

# Number of images to generate for visualization during training
num_test_samples = 16
fixed_noise = torch.randn(num_test_samples, latent_dim, device=device)

print("Starting Training Loop...")

for epoch in range(num_epochs):
    for i, (real_imgs, _) in enumerate(train_loader):
        # Get the batch size
        batch_size = real_imgs.size(0)
        
        # Move data to the device
        real_imgs = real_imgs.to(device)
        
        # Create labels: label smoothing for stability
        real_labels = torch.full((batch_size, 1), label_smoothing, device=device)  # 0.9 instead of 1
        fake_labels = torch.zeros(batch_size, 1, device=device)
        
        # -----------------
        # Train Discriminator
        # -----------------
        # Train the discriminator more frequently than the generator
        for _ in range(1):  # Can be adjusted to 2 or 3 iterations if necessary
            optimizer_D.zero_grad()
            
            # Measure the discriminator's ability to distinguish between real and fake images
            real_validity = discriminator(real_imgs)
            
            # Add noise to the labels (another form of label smoothing)
            real_labels_noisy = real_labels - 0.1 * torch.rand(real_labels.size(), device=device)
            
            # Generate a batch of fake images
            z = torch.randn(batch_size, latent_dim, device=device)
            fake_imgs = generator(z)
            fake_validity = discriminator(fake_imgs.detach())
            
            # Add noise to the discriminator inputs to improve generalization
            if np.random.random() < 0.1:  # 10% probability
                # Add small Gaussian noise to the real images
                real_imgs = real_imgs + 0.1 * torch.randn_like(real_imgs)
            
            # Calculate loss
            real_loss = adversarial_loss(real_validity, real_labels_noisy)
            fake_loss = adversarial_loss(fake_validity, fake_labels)
            d_loss = (real_loss + fake_loss) / 2
            
            # Backpropagation
            d_loss.backward()
            optimizer_D.step()
        
        # -----------------
        # Train Generator
        # -----------------
        optimizer_G.zero_grad()
        
        # Generate a new batch of fake images
        z = torch.randn(batch_size, latent_dim, device=device)
        fake_imgs = generator(z)
        
        # Regularization technique to avoid mode collapse: add noise to the latent vector
        if epoch > 10 and np.random.random() < 0.2:  # After epoch 10, 20% of the time
            # Add a small noise to the latent vector
            z = z + 0.1 * torch.randn_like(z)
            fake_imgs = generator(z)
        
        # Try to fool the discriminator
        validity = discriminator(fake_imgs)
        
        # Calculate the generator's loss
        g_loss = adversarial_loss(validity, real_labels)
        
        # Backpropagation
        g_loss.backward()
        optimizer_G.step()
        
        # Store losses for plotting
        G_losses.append(g_loss.item())
        D_losses.append(d_loss.item())
        
        # Print progress
        if i % 100 == 0:
            print(
                f"[Epoch {epoch}/{num_epochs}] [Batch {i}/{len(train_loader)}] "
                f"[D loss: {d_loss.item():.4f}] [G loss: {g_loss.item():.4f}]"
            )
        
        # Learning rate scheduling
        # Gradually reduce the generator's learning rate
        if epoch > 30 and i % 500 == 0:
            for param_group in optimizer_G.param_groups:
                param_group['lr'] = max(param_group['lr'] * 0.99, 1e-5)
    
    # Generate and save images after each epoch
    with torch.no_grad():
        # Generate images with fixed noise to monitor progress
        fake_images = generator(fixed_noise).detach().cpu()
        generated_images.append(fake_images)
        
        # Every 5 epochs, generate images with slightly varied noise
        # to evaluate mode collapse issues
        if epoch % 5 == 0 and epoch > 0:
            varied_noise = fixed_noise + 0.1 * torch.randn_like(fixed_noise)
            varied_images = generator(varied_noise).detach().cpu()
            
            # Display some images during training for monitoring
            plt.figure(figsize=(10, 5))
            plt.subplot(1, 2, 1)
            plt.axis("off")
            plt.title(f"Epoch {epoch} - Fixed Noise")
            plt.imshow(
                np.transpose(
                    vutils.make_grid(fake_images[:8], nrow=4, padding=2, normalize=True).numpy(),
                    (1, 2, 0)
                ),
                cmap='gray'
            )
            
            plt.subplot(1, 2, 2)
            plt.axis("off")
            plt.title(f"Epoch {epoch} - Varied Noise")
            plt.imshow(
                np.transpose(
                    vutils.make_grid(varied_images[:8], nrow=4, padding=2, normalize=True).numpy(),
                    (1, 2, 0)
                ),
                cmap='gray'
            )
            plt.show()
# Out:
# Starting Training Loop...
# Initializing Discriminator linear layer with input size: 4096
# [Epoch 0/50] [Batch 0/1950] [D loss: 0.7288] [G loss: 0.6863]
# [Epoch 0/50] [Batch 100/1950] [D loss: 0.6820] [G loss: 0.8727]
# [Epoch 0/50] [Batch 200/1950] [D loss: 0.6369] [G loss: 0.9277]
# [Epoch 0/50] [Batch 300/1950] [D loss: 0.6532] [G loss: 0.8956]
# [Epoch 0/50] [Batch 400/1950] [D loss: 0.6695] [G loss: 0.8806]
# [Epoch 0/50] [Batch 500/1950] [D loss: 0.6425] [G loss: 0.8878]
# [Epoch 0/50] [Batch 600/1950] [D loss: 0.6621] [G loss: 0.7887]
# [Epoch 0/50] [Batch 700/1950] [D loss: 0.6689] [G loss: 0.9124]
# [Epoch 0/50] [Batch 800/1950] [D loss: 0.6720] [G loss: 0.8740]
# [Epoch 0/50] [Batch 900/1950] [D loss: 0.6698] [G loss: 0.9161]
# [Epoch 0/50] [Batch 1000/1950] [D loss: 0.6760] [G loss: 0.8887]
# [Epoch 0/50] [Batch 1100/1950] [D loss: 0.6821] [G loss: 0.8996]
# [Epoch 0/50] [Batch 1200/1950] [D loss: 0.6822] [G loss: 0.8908]
# [Epoch 0/50] [Batch 1300/1950] [D loss: 0.6499] [G loss: 0.8478]
# [Epoch 0/50] [Batch 1400/1950] [D loss: 0.6720] [G loss: 0.8681]
# [Epoch 0/50] [Batch 1500/1950] [D loss: 0.6613] [G loss: 0.9313]
# [Epoch 0/50] [Batch 1600/1950] [D loss: 0.6742] [G loss: 0.8569]
# [Epoch 0/50] [Batch 1700/1950] [D loss: 0.6552] [G loss: 0.8536]
# [Epoch 0/50] [Batch 1800/1950] [D loss: 0.6543] [G loss: 0.8886]
# [Epoch 0/50] [Batch 1900/1950] [D loss: 0.6583] [G loss: 0.8458]
# [Epoch 1/50] [Batch 0/1950] [D loss: 0.6781] [G loss: 0.8558]
# [Epoch 1/50] [Batch 100/1950] [D loss: 0.6648] [G loss: 0.8490]
# [Epoch 1/50] [Batch 200/1950] [D loss: 0.6572] [G loss: 0.8048]
# [Epoch 1/50] [Batch 300/1950] [D loss: 0.6707] [G loss: 0.8475]
# [Epoch 1/50] [Batch 400/1950] [D loss: 0.6817] [G loss: 0.8837]
# [Epoch 1/50] [Batch 500/1950] [D loss: 0.6724] [G loss: 0.8881]
# [Epoch 1/50] [Batch 600/1950] [D loss: 0.6557] [G loss: 0.8383]
# [Epoch 1/50] [Batch 700/1950] [D loss: 0.6705] [G loss: 0.8589]
# [Epoch 1/50] [Batch 800/1950] [D loss: 0.6711] [G loss: 0.8699]
# [Epoch 1/50] [Batch 900/1950] [D loss: 0.6596] [G loss: 0.8655]
# [Epoch 1/50] [Batch 1000/1950] [D loss: 0.6654] [G loss: 0.9017]
# [Epoch 1/50] [Batch 1100/1950] [D loss: 0.6594] [G loss: 0.8133]
# [Epoch 1/50] [Batch 1200/1950] [D loss: 0.6661] [G loss: 0.8801]
# [Epoch 1/50] [Batch 1300/1950] [D loss: 0.6662] [G loss: 0.8769]
# [Epoch 1/50] [Batch 1400/1950] [D loss: 0.6804] [G loss: 0.8686]
# [Epoch 1/50] [Batch 1500/1950] [D loss: 0.6639] [G loss: 0.8376]
# [Epoch 1/50] [Batch 1600/1950] [D loss: 0.6834] [G loss: 0.8230]
# [Epoch 1/50] [Batch 1700/1950] [D loss: 0.6925] [G loss: 0.8960]
# [Epoch 1/50] [Batch 1800/1950] [D loss: 0.7002] [G loss: 0.8782]
# [Epoch 1/50] [Batch 1900/1950] [D loss: 0.6689] [G loss: 0.8775]
# [Epoch 2/50] [Batch 0/1950] [D loss: 0.6846] [G loss: 0.8537]
# [Epoch 2/50] [Batch 100/1950] [D loss: 0.6505] [G loss: 0.8452]
# [Epoch 2/50] [Batch 200/1950] [D loss: 0.6849] [G loss: 0.8590]
# [Epoch 2/50] [Batch 300/1950] [D loss: 0.6570] [G loss: 0.8402]
# [Epoch 2/50] [Batch 400/1950] [D loss: 0.6668] [G loss: 0.8810]
# [Epoch 2/50] [Batch 500/1950] [D loss: 0.6752] [G loss: 0.8294]
# [Epoch 2/50] [Batch 600/1950] [D loss: 0.6741] [G loss: 0.8719]
# [Epoch 2/50] [Batch 700/1950] [D loss: 0.6801] [G loss: 0.8679]
# [Epoch 2/50] [Batch 800/1950] [D loss: 0.6738] [G loss: 0.8571]
# [Epoch 2/50] [Batch 900/1950] [D loss: 0.6606] [G loss: 0.8707]
# [Epoch 2/50] [Batch 1000/1950] [D loss: 0.6608] [G loss: 0.8343]
# [Epoch 2/50] [Batch 1100/1950] [D loss: 0.6653] [G loss: 0.8696]
# [Epoch 2/50] [Batch 1200/1950] [D loss: 0.6599] [G loss: 0.8556]
# [Epoch 2/50] [Batch 1300/1950] [D loss: 0.6626] [G loss: 0.8680]
# [Epoch 2/50] [Batch 1400/1950] [D loss: 0.6733] [G loss: 0.8816]
# [Epoch 2/50] [Batch 1500/1950] [D loss: 0.6636] [G loss: 0.8399]
# [Epoch 2/50] [Batch 1600/1950] [D loss: 0.6714] [G loss: 0.8759]
# [Epoch 2/50] [Batch 1700/1950] [D loss: 0.6698] [G loss: 0.8614]
# [Epoch 2/50] [Batch 1800/1950] [D loss: 0.6642] [G loss: 0.8682]
# [Epoch 2/50] [Batch 1900/1950] [D loss: 0.6693] [G loss: 0.8382]
# [Epoch 3/50] [Batch 0/1950] [D loss: 0.6604] [G loss: 0.8543]
# [Epoch 3/50] [Batch 100/1950] [D loss: 0.6782] [G loss: 0.8537]
# [Epoch 3/50] [Batch 200/1950] [D loss: 0.6692] [G loss: 0.8862]
# [Epoch 3/50] [Batch 300/1950] [D loss: 0.6710] [G loss: 0.8573]
# [Epoch 3/50] [Batch 400/1950] [D loss: 0.6732] [G loss: 0.8290]
# [Epoch 3/50] [Batch 500/1950] [D loss: 0.6694] [G loss: 0.8256]
# [Epoch 3/50] [Batch 600/1950] [D loss: 0.6493] [G loss: 0.8664]
# [Epoch 3/50] [Batch 700/1950] [D loss: 0.6598] [G loss: 0.8335]
# [Epoch 3/50] [Batch 800/1950] [D loss: 0.6568] [G loss: 0.8551]
# [Epoch 3/50] [Batch 900/1950] [D loss: 0.6697] [G loss: 0.8571]
# [Epoch 3/50] [Batch 1000/1950] [D loss: 0.6706] [G loss: 0.8430]
# [Epoch 3/50] [Batch 1100/1950] [D loss: 0.6585] [G loss: 0.8437]
# [Epoch 3/50] [Batch 1200/1950] [D loss: 0.6662] [G loss: 0.8901]
# [Epoch 3/50] [Batch 1300/1950] [D loss: 0.6736] [G loss: 0.8311]
# [Epoch 3/50] [Batch 1400/1950] [D loss: 0.6746] [G loss: 0.8546]
# [Epoch 3/50] [Batch 1500/1950] [D loss: 0.6712] [G loss: 0.8687]
# [Epoch 3/50] [Batch 1600/1950] [D loss: 0.6649] [G loss: 0.8665]
# [Epoch 3/50] [Batch 1700/1950] [D loss: 0.6647] [G loss: 0.8204]
# [Epoch 3/50] [Batch 1800/1950] [D loss: 0.6760] [G loss: 0.8308]
# [Epoch 3/50] [Batch 1900/1950] [D loss: 0.6752] [G loss: 0.8770]
# [Epoch 4/50] [Batch 0/1950] [D loss: 0.6846] [G loss: 0.8496]
# [Epoch 4/50] [Batch 100/1950] [D loss: 0.6709] [G loss: 0.8428]
# [Epoch 4/50] [Batch 200/1950] [D loss: 0.6740] [G loss: 0.8480]
# [Epoch 4/50] [Batch 300/1950] [D loss: 0.6654] [G loss: 0.8690]
# [Epoch 4/50] [Batch 400/1950] [D loss: 0.6596] [G loss: 0.8579]
# [Epoch 4/50] [Batch 500/1950] [D loss: 0.6545] [G loss: 0.8569]
# [Epoch 4/50] [Batch 600/1950] [D loss: 0.6928] [G loss: 0.8746]
# [Epoch 4/50] [Batch 700/1950] [D loss: 0.6728] [G loss: 0.8245]
# [Epoch 4/50] [Batch 800/1950] [D loss: 0.6737] [G loss: 0.8669]
# [Epoch 4/50] [Batch 900/1950] [D loss: 0.6553] [G loss: 0.8457]
# [Epoch 4/50] [Batch 1000/1950] [D loss: 0.6658] [G loss: 0.8819]
# [Epoch 4/50] [Batch 1100/1950] [D loss: 0.6724] [G loss: 0.8777]
# [Epoch 4/50] [Batch 1200/1950] [D loss: 0.6690] [G loss: 0.8813]
# [Epoch 4/50] [Batch 1300/1950] [D loss: 0.6724] [G loss: 0.8521]
# [Epoch 4/50] [Batch 1400/1950] [D loss: 0.6645] [G loss: 0.8356]
# [Epoch 4/50] [Batch 1500/1950] [D loss: 0.6598] [G loss: 0.8745]
# [Epoch 4/50] [Batch 1600/1950] [D loss: 0.6759] [G loss: 0.8172]
# [Epoch 4/50] [Batch 1700/1950] [D loss: 0.6555] [G loss: 0.8609]
# [Epoch 4/50] [Batch 1800/1950] [D loss: 0.6659] [G loss: 0.8464]
# [Epoch 4/50] [Batch 1900/1950] [D loss: 0.6574] [G loss: 0.8449]
# [Epoch 5/50] [Batch 0/1950] [D loss: 0.6602] [G loss: 0.8542]
# [Epoch 5/50] [Batch 100/1950] [D loss: 0.6747] [G loss: 0.8708]
# [Epoch 5/50] [Batch 200/1950] [D loss: 0.6615] [G loss: 0.8450]
# [Epoch 5/50] [Batch 300/1950] [D loss: 0.6622] [G loss: 0.8582]
# [Epoch 5/50] [Batch 400/1950] [D loss: 0.6773] [G loss: 0.8679]
# [Epoch 5/50] [Batch 500/1950] [D loss: 0.6683] [G loss: 0.8746]
# [Epoch 5/50] [Batch 600/1950] [D loss: 0.6726] [G loss: 0.8317]
# [Epoch 5/50] [Batch 700/1950] [D loss: 0.6505] [G loss: 0.8633]
# [Epoch 5/50] [Batch 800/1950] [D loss: 0.6689] [G loss: 0.8817]
# [Epoch 5/50] [Batch 900/1950] [D loss: 0.6639] [G loss: 0.8794]
# [Epoch 5/50] [Batch 1000/1950] [D loss: 0.6655] [G loss: 0.8809]
# [Epoch 5/50] [Batch 1100/1950] [D loss: 0.6566] [G loss: 0.8712]
# [Epoch 5/50] [Batch 1200/1950] [D loss: 0.6743] [G loss: 0.8845]
# [Epoch 5/50] [Batch 1300/1950] [D loss: 0.6800] [G loss: 0.8447]
# [Epoch 5/50] [Batch 1400/1950] [D loss: 0.6626] [G loss: 0.8746]
# [Epoch 5/50] [Batch 1500/1950] [D loss: 0.6577] [G loss: 0.8686]
# [Epoch 5/50] [Batch 1600/1950] [D loss: 0.6715] [G loss: 0.8530]
# [Epoch 5/50] [Batch 1700/1950] [D loss: 0.6698] [G loss: 0.8485]
# [Epoch 5/50] [Batch 1800/1950] [D loss: 0.6613] [G loss: 0.8517]
# [Epoch 5/50] [Batch 1900/1950] [D loss: 0.6706] [G loss: 0.8536]
# [Epoch 6/50] [Batch 0/1950] [D loss: 0.6626] [G loss: 0.8504]
# [Epoch 6/50] [Batch 100/1950] [D loss: 0.6544] [G loss: 0.8426]
# [Epoch 6/50] [Batch 200/1950] [D loss: 0.6619] [G loss: 0.8823]
# [Epoch 6/50] [Batch 300/1950] [D loss: 0.6559] [G loss: 0.8681]
# [Epoch 6/50] [Batch 400/1950] [D loss: 0.6744] [G loss: 0.8633]
# [Epoch 6/50] [Batch 500/1950] [D loss: 0.6594] [G loss: 0.8637]
# [Epoch 6/50] [Batch 600/1950] [D loss: 0.6572] [G loss: 0.8883]
# [Epoch 6/50] [Batch 700/1950] [D loss: 0.6569] [G loss: 0.8578]
# [Epoch 6/50] [Batch 800/1950] [D loss: 0.6716] [G loss: 0.9241]
# [Epoch 6/50] [Batch 900/1950] [D loss: 0.6653] [G loss: 0.8774]
# [Epoch 6/50] [Batch 1000/1950] [D loss: 0.6725] [G loss: 0.8410]
# [Epoch 6/50] [Batch 1100/1950] [D loss: 0.6800] [G loss: 0.8682]
# [Epoch 6/50] [Batch 1200/1950] [D loss: 0.6451] [G loss: 0.9109]
# [Epoch 6/50] [Batch 1300/1950] [D loss: 0.6687] [G loss: 0.8727]
# [Epoch 6/50] [Batch 1400/1950] [D loss: 0.6746] [G loss: 0.8216]
# [Epoch 6/50] [Batch 1500/1950] [D loss: 0.6716] [G loss: 0.8717]
# [Epoch 6/50] [Batch 1600/1950] [D loss: 0.6656] [G loss: 0.8572]
# [Epoch 6/50] [Batch 1700/1950] [D loss: 0.6603] [G loss: 0.8824]
# [Epoch 6/50] [Batch 1800/1950] [D loss: 0.6778] [G loss: 0.8480]
# [Epoch 6/50] [Batch 1900/1950] [D loss: 0.6610] [G loss: 0.8839]
# [Epoch 7/50] [Batch 0/1950] [D loss: 0.6561] [G loss: 0.8359]
# [Epoch 7/50] [Batch 100/1950] [D loss: 0.6546] [G loss: 0.8548]
# [Epoch 7/50] [Batch 200/1950] [D loss: 0.6641] [G loss: 0.8429]
# [Epoch 7/50] [Batch 300/1950] [D loss: 0.6630] [G loss: 0.8495]
# [Epoch 7/50] [Batch 400/1950] [D loss: 0.6740] [G loss: 0.8460]
# [Epoch 7/50] [Batch 500/1950] [D loss: 0.6731] [G loss: 0.8611]
# [Epoch 7/50] [Batch 600/1950] [D loss: 0.6579] [G loss: 0.8534]
# [Epoch 7/50] [Batch 700/1950] [D loss: 0.6638] [G loss: 0.8665]
# [Epoch 7/50] [Batch 800/1950] [D loss: 0.6615] [G loss: 0.8842]
# [Epoch 7/50] [Batch 900/1950] [D loss: 0.6526] [G loss: 0.8431]
# [Epoch 7/50] [Batch 1000/1950] [D loss: 0.6613] [G loss: 0.8753]
# [Epoch 7/50] [Batch 1100/1950] [D loss: 0.6973] [G loss: 0.8597]
# [Epoch 7/50] [Batch 1200/1950] [D loss: 0.6550] [G loss: 0.8806]
# [Epoch 7/50] [Batch 1300/1950] [D loss: 0.6660] [G loss: 0.8389]
# [Epoch 7/50] [Batch 1400/1950] [D loss: 0.6727] [G loss: 0.8294]
# [Epoch 7/50] [Batch 1500/1950] [D loss: 0.6717] [G loss: 0.8728]
# [Epoch 7/50] [Batch 1600/1950] [D loss: 0.6674] [G loss: 0.8681]
# [Epoch 7/50] [Batch 1700/1950] [D loss: 0.6804] [G loss: 0.8490]
# [Epoch 7/50] [Batch 1800/1950] [D loss: 0.6659] [G loss: 0.8629]
# [Epoch 7/50] [Batch 1900/1950] [D loss: 0.6553] [G loss: 0.8379]
# [Epoch 8/50] [Batch 0/1950] [D loss: 0.6731] [G loss: 0.8720]
# [Epoch 8/50] [Batch 100/1950] [D loss: 0.6731] [G loss: 0.8560]
# [Epoch 8/50] [Batch 200/1950] [D loss: 0.6709] [G loss: 0.8487]
# [Epoch 8/50] [Batch 300/1950] [D loss: 0.6764] [G loss: 0.8609]
# [Epoch 8/50] [Batch 400/1950] [D loss: 0.6493] [G loss: 0.8841]
# [Epoch 8/50] [Batch 500/1950] [D loss: 0.6571] [G loss: 0.8728]
# [Epoch 8/50] [Batch 600/1950] [D loss: 0.6708] [G loss: 0.8192]
# [Epoch 8/50] [Batch 700/1950] [D loss: 0.6701] [G loss: 0.8758]
# [Epoch 8/50] [Batch 800/1950] [D loss: 0.6575] [G loss: 0.8850]
# [Epoch 8/50] [Batch 900/1950] [D loss: 0.6780] [G loss: 0.8737]
# [Epoch 8/50] [Batch 1000/1950] [D loss: 0.6743] [G loss: 0.8458]
# [Epoch 8/50] [Batch 1100/1950] [D loss: 0.6636] [G loss: 0.8704]
# [Epoch 8/50] [Batch 1200/1950] [D loss: 0.6699] [G loss: 0.8615]
# [Epoch 8/50] [Batch 1300/1950] [D loss: 0.6670] [G loss: 0.8659]
# [Epoch 8/50] [Batch 1400/1950] [D loss: 0.6667] [G loss: 0.8679]
# [Epoch 8/50] [Batch 1500/1950] [D loss: 0.6512] [G loss: 0.8598]
# [Epoch 8/50] [Batch 1600/1950] [D loss: 0.6807] [G loss: 0.8671]
# [Epoch 8/50] [Batch 1700/1950] [D loss: 0.6544] [G loss: 0.8482]
# [Epoch 8/50] [Batch 1800/1950] [D loss: 0.6624] [G loss: 0.8844]
# [Epoch 8/50] [Batch 1900/1950] [D loss: 0.6636] [G loss: 0.8596]
# [Epoch 9/50] [Batch 0/1950] [D loss: 0.6575] [G loss: 0.8476]
# [Epoch 9/50] [Batch 100/1950] [D loss: 0.6644] [G loss: 0.8623]
# [Epoch 9/50] [Batch 200/1950] [D loss: 0.6731] [G loss: 0.8610]
# [Epoch 9/50] [Batch 300/1950] [D loss: 0.6681] [G loss: 0.8872]
# [Epoch 9/50] [Batch 400/1950] [D loss: 0.6642] [G loss: 0.8695]
# [Epoch 9/50] [Batch 500/1950] [D loss: 0.6682] [G loss: 0.8622]
# [Epoch 9/50] [Batch 600/1950] [D loss: 0.6563] [G loss: 0.8751]
# [Epoch 9/50] [Batch 700/1950] [D loss: 0.6591] [G loss: 0.8747]
# [Epoch 9/50] [Batch 800/1950] [D loss: 0.6748] [G loss: 0.8300]
# [Epoch 9/50] [Batch 900/1950] [D loss: 0.6660] [G loss: 0.8560]
# [Epoch 9/50] [Batch 1000/1950] [D loss: 0.6574] [G loss: 0.8626]
# [Epoch 9/50] [Batch 1100/1950] [D loss: 0.6645] [G loss: 0.8625]
# [Epoch 9/50] [Batch 1200/1950] [D loss: 0.6616] [G loss: 0.8580]
# [Epoch 9/50] [Batch 1300/1950] [D loss: 0.6543] [G loss: 0.8624]
# [Epoch 9/50] [Batch 1400/1950] [D loss: 0.6545] [G loss: 0.8565]
# [Epoch 9/50] [Batch 1500/1950] [D loss: 0.6463] [G loss: 0.8336]
# [Epoch 9/50] [Batch 1600/1950] [D loss: 0.6494] [G loss: 0.8213]
# [Epoch 9/50] [Batch 1700/1950] [D loss: 0.6759] [G loss: 0.8587]
# [Epoch 9/50] [Batch 1800/1950] [D loss: 0.6528] [G loss: 0.8490]
# [Epoch 9/50] [Batch 1900/1950] [D loss: 0.6705] [G loss: 0.8409]
# [Epoch 10/50] [Batch 0/1950] [D loss: 0.6553] [G loss: 0.8452]
# [Epoch 10/50] [Batch 100/1950] [D loss: 0.6558] [G loss: 0.8471]
# [Epoch 10/50] [Batch 200/1950] [D loss: 0.6619] [G loss: 0.8629]
# [Epoch 10/50] [Batch 300/1950] [D loss: 0.6592] [G loss: 0.8580]
# [Epoch 10/50] [Batch 400/1950] [D loss: 0.6651] [G loss: 0.8887]
# [Epoch 10/50] [Batch 500/1950] [D loss: 0.6643] [G loss: 0.8292]
# [Epoch 10/50] [Batch 600/1950] [D loss: 0.6619] [G loss: 0.8564]
# [Epoch 10/50] [Batch 700/1950] [D loss: 0.6785] [G loss: 0.8381]
# [Epoch 10/50] [Batch 800/1950] [D loss: 0.6668] [G loss: 0.8840]
# [Epoch 10/50] [Batch 900/1950] [D loss: 0.6591] [G loss: 0.8582]
# [Epoch 10/50] [Batch 1000/1950] [D loss: 0.6428] [G loss: 0.8797]
# [Epoch 10/50] [Batch 1100/1950] [D loss: 0.6786] [G loss: 0.8663]
# [Epoch 10/50] [Batch 1200/1950] [D loss: 0.6722] [G loss: 0.8531]
# [Epoch 10/50] [Batch 1300/1950] [D loss: 0.6694] [G loss: 0.8768]
# [Epoch 10/50] [Batch 1400/1950] [D loss: 0.6604] [G loss: 0.8565]
# [Epoch 10/50] [Batch 1500/1950] [D loss: 0.6817] [G loss: 0.8200]
# [Epoch 10/50] [Batch 1600/1950] [D loss: 0.6670] [G loss: 0.8702]
# [Epoch 10/50] [Batch 1700/1950] [D loss: 0.6564] [G loss: 0.8634]
# [Epoch 10/50] [Batch 1800/1950] [D loss: 0.6611] [G loss: 0.8986]
# [Epoch 10/50] [Batch 1900/1950] [D loss: 0.6648] [G loss: 0.8397]
# [Epoch 11/50] [Batch 0/1950] [D loss: 0.6730] [G loss: 0.8442]
# [Epoch 11/50] [Batch 100/1950] [D loss: 0.6585] [G loss: 0.8623]
# [Epoch 11/50] [Batch 200/1950] [D loss: 0.6636] [G loss: 0.8548]
# [Epoch 11/50] [Batch 300/1950] [D loss: 0.6621] [G loss: 0.8672]
# [Epoch 11/50] [Batch 400/1950] [D loss: 0.6659] [G loss: 0.8446]
# [Epoch 11/50] [Batch 500/1950] [D loss: 0.6603] [G loss: 0.8426]
# [Epoch 11/50] [Batch 600/1950] [D loss: 0.6640] [G loss: 0.8646]
# [Epoch 11/50] [Batch 700/1950] [D loss: 0.6679] [G loss: 0.8324]
# [Epoch 11/50] [Batch 800/1950] [D loss: 0.6771] [G loss: 0.8857]
# [Epoch 11/50] [Batch 900/1950] [D loss: 0.6715] [G loss: 0.8466]
# [Epoch 11/50] [Batch 1000/1950] [D loss: 0.6531] [G loss: 0.8463]
# [Epoch 11/50] [Batch 1100/1950] [D loss: 0.6661] [G loss: 0.8372]
# [Epoch 11/50] [Batch 1200/1950] [D loss: 0.6695] [G loss: 0.8864]
# [Epoch 11/50] [Batch 1300/1950] [D loss: 0.6548] [G loss: 0.8627]
# [Epoch 11/50] [Batch 1400/1950] [D loss: 0.6728] [G loss: 0.8607]
# [Epoch 11/50] [Batch 1500/1950] [D loss: 0.6572] [G loss: 0.8716]
# [Epoch 11/50] [Batch 1600/1950] [D loss: 0.6744] [G loss: 0.8666]
# [Epoch 11/50] [Batch 1700/1950] [D loss: 0.6842] [G loss: 0.8733]
# [Epoch 11/50] [Batch 1800/1950] [D loss: 0.6637] [G loss: 0.8845]
# [Epoch 11/50] [Batch 1900/1950] [D loss: 0.6728] [G loss: 0.8413]
# [Epoch 12/50] [Batch 0/1950] [D loss: 0.6672] [G loss: 0.8948]
# [Epoch 12/50] [Batch 100/1950] [D loss: 0.6853] [G loss: 0.8578]
# [Epoch 12/50] [Batch 200/1950] [D loss: 0.6767] [G loss: 0.8199]
# [Epoch 12/50] [Batch 300/1950] [D loss: 0.6514] [G loss: 0.9101]
# [Epoch 12/50] [Batch 400/1950] [D loss: 0.6693] [G loss: 0.8689]
# [Epoch 12/50] [Batch 500/1950] [D loss: 0.6547] [G loss: 0.8746]
# [Epoch 12/50] [Batch 600/1950] [D loss: 0.7056] [G loss: 0.8707]
# [Epoch 12/50] [Batch 700/1950] [D loss: 0.6435] [G loss: 0.8659]
# [Epoch 12/50] [Batch 800/1950] [D loss: 0.6616] [G loss: 0.8203]
# [Epoch 12/50] [Batch 900/1950] [D loss: 0.6824] [G loss: 0.8369]
# [Epoch 12/50] [Batch 1000/1950] [D loss: 0.6762] [G loss: 0.8627]
# [Epoch 12/50] [Batch 1100/1950] [D loss: 0.6719] [G loss: 0.8465]
# [Epoch 12/50] [Batch 1200/1950] [D loss: 0.6689] [G loss: 0.8817]
# [Epoch 12/50] [Batch 1300/1950] [D loss: 0.6589] [G loss: 0.8487]
# [Epoch 12/50] [Batch 1400/1950] [D loss: 0.6752] [G loss: 0.8936]
# [Epoch 12/50] [Batch 1500/1950] [D loss: 0.6668] [G loss: 0.8558]
# [Epoch 12/50] [Batch 1600/1950] [D loss: 0.6562] [G loss: 0.8506]
# [Epoch 12/50] [Batch 1700/1950] [D loss: 0.6644] [G loss: 0.8563]
# [Epoch 12/50] [Batch 1800/1950] [D loss: 0.6733] [G loss: 0.8544]
# [Epoch 12/50] [Batch 1900/1950] [D loss: 0.6794] [G loss: 0.8469]
# [Epoch 13/50] [Batch 0/1950] [D loss: 0.6599] [G loss: 0.8520]
# [Epoch 13/50] [Batch 100/1950] [D loss: 0.6901] [G loss: 0.8911]
# [Epoch 13/50] [Batch 200/1950] [D loss: 0.6605] [G loss: 0.8436]
# [Epoch 13/50] [Batch 300/1950] [D loss: 0.6693] [G loss: 0.8882]
# [Epoch 13/50] [Batch 400/1950] [D loss: 0.6603] [G loss: 0.8496]
# [Epoch 13/50] [Batch 500/1950] [D loss: 0.6698] [G loss: 0.8457]
# [Epoch 13/50] [Batch 600/1950] [D loss: 0.6708] [G loss: 0.8704]
# [Epoch 13/50] [Batch 700/1950] [D loss: 0.6778] [G loss: 0.8469]
# [Epoch 13/50] [Batch 800/1950] [D loss: 0.6834] [G loss: 0.8349]
# [Epoch 13/50] [Batch 900/1950] [D loss: 0.6595] [G loss: 0.8449]
# [Epoch 13/50] [Batch 1000/1950] [D loss: 0.6683] [G loss: 0.8453]
# [Epoch 13/50] [Batch 1100/1950] [D loss: 0.6609] [G loss: 0.8443]
# [Epoch 13/50] [Batch 1200/1950] [D loss: 0.6549] [G loss: 0.8748]
# [Epoch 13/50] [Batch 1300/1950] [D loss: 0.6549] [G loss: 0.8414]
# [Epoch 13/50] [Batch 1400/1950] [D loss: 0.6810] [G loss: 0.8398]
# [Epoch 13/50] [Batch 1500/1950] [D loss: 0.6722] [G loss: 0.8636]
# [Epoch 13/50] [Batch 1600/1950] [D loss: 0.6724] [G loss: 0.8614]
# [Epoch 13/50] [Batch 1700/1950] [D loss: 0.6600] [G loss: 0.8537]
# [Epoch 13/50] [Batch 1800/1950] [D loss: 0.6612] [G loss: 0.8615]
# [Epoch 13/50] [Batch 1900/1950] [D loss: 0.6805] [G loss: 0.8587]
# [Epoch 14/50] [Batch 0/1950] [D loss: 0.6551] [G loss: 0.8525]
# [Epoch 14/50] [Batch 100/1950] [D loss: 0.6685] [G loss: 0.8542]
# [Epoch 14/50] [Batch 200/1950] [D loss: 0.6645] [G loss: 0.8549]
# [Epoch 14/50] [Batch 300/1950] [D loss: 0.6639] [G loss: 0.8929]
# [Epoch 14/50] [Batch 400/1950] [D loss: 0.6611] [G loss: 0.8761]
# [Epoch 14/50] [Batch 500/1950] [D loss: 0.6645] [G loss: 0.8786]
# [Epoch 14/50] [Batch 600/1950] [D loss: 0.6795] [G loss: 0.8486]
# [Epoch 14/50] [Batch 700/1950] [D loss: 0.6702] [G loss: 0.9114]
# [Epoch 14/50] [Batch 800/1950] [D loss: 0.6674] [G loss: 0.8571]
# [Epoch 14/50] [Batch 900/1950] [D loss: 0.6600] [G loss: 0.8435]
# [Epoch 14/50] [Batch 1000/1950] [D loss: 0.6795] [G loss: 0.8689]
# [Epoch 14/50] [Batch 1100/1950] [D loss: 0.6657] [G loss: 0.8738]
# [Epoch 14/50] [Batch 1200/1950] [D loss: 0.6794] [G loss: 0.8645]
# [Epoch 14/50] [Batch 1300/1950] [D loss: 0.6468] [G loss: 0.8593]
# [Epoch 14/50] [Batch 1400/1950] [D loss: 0.6734] [G loss: 0.8829]
# [Epoch 14/50] [Batch 1500/1950] [D loss: 0.6597] [G loss: 0.8499]
# [Epoch 14/50] [Batch 1600/1950] [D loss: 0.6664] [G loss: 0.8551]
# [Epoch 14/50] [Batch 1700/1950] [D loss: 0.6776] [G loss: 0.8661]
# [Epoch 14/50] [Batch 1800/1950] [D loss: 0.6515] [G loss: 0.8597]
# [Epoch 14/50] [Batch 1900/1950] [D loss: 0.6716] [G loss: 0.8676]
# [Epoch 15/50] [Batch 0/1950] [D loss: 0.6584] [G loss: 0.8571]
# [Epoch 15/50] [Batch 100/1950] [D loss: 0.6725] [G loss: 0.8698]
# [Epoch 15/50] [Batch 200/1950] [D loss: 0.6844] [G loss: 0.8586]
# [Epoch 15/50] [Batch 300/1950] [D loss: 0.6567] [G loss: 0.8251]
# [Epoch 15/50] [Batch 400/1950] [D loss: 0.6559] [G loss: 0.8467]
# [Epoch 15/50] [Batch 500/1950] [D loss: 0.6773] [G loss: 0.8743]
# [Epoch 15/50] [Batch 600/1950] [D loss: 0.6596] [G loss: 0.8520]
# [Epoch 15/50] [Batch 700/1950] [D loss: 0.6816] [G loss: 0.9193]
# [Epoch 15/50] [Batch 800/1950] [D loss: 0.6699] [G loss: 0.8550]
# [Epoch 15/50] [Batch 900/1950] [D loss: 0.6711] [G loss: 0.8764]
# [Epoch 15/50] [Batch 1000/1950] [D loss: 0.6521] [G loss: 0.8823]
# [Epoch 15/50] [Batch 1100/1950] [D loss: 0.6601] [G loss: 0.8657]
# [Epoch 15/50] [Batch 1200/1950] [D loss: 0.6518] [G loss: 0.8513]
# [Epoch 15/50] [Batch 1300/1950] [D loss: 0.6758] [G loss: 0.8474]
# [Epoch 15/50] [Batch 1400/1950] [D loss: 0.6606] [G loss: 0.8448]
# [Epoch 15/50] [Batch 1500/1950] [D loss: 0.6562] [G loss: 0.9304]
# [Epoch 15/50] [Batch 1600/1950] [D loss: 0.6732] [G loss: 0.8592]
# [Epoch 15/50] [Batch 1700/1950] [D loss: 0.6789] [G loss: 0.8433]
# [Epoch 15/50] [Batch 1800/1950] [D loss: 0.6503] [G loss: 0.8992]
# [Epoch 15/50] [Batch 1900/1950] [D loss: 0.6634] [G loss: 0.8333]
# [Epoch 16/50] [Batch 0/1950] [D loss: 0.6644] [G loss: 0.8474]
# [Epoch 16/50] [Batch 100/1950] [D loss: 0.6570] [G loss: 0.8799]
# [Epoch 16/50] [Batch 200/1950] [D loss: 0.6588] [G loss: 0.8308]
# [Epoch 16/50] [Batch 300/1950] [D loss: 0.6666] [G loss: 0.8757]
# [Epoch 16/50] [Batch 400/1950] [D loss: 0.6608] [G loss: 0.8431]
# [Epoch 16/50] [Batch 500/1950] [D loss: 0.6538] [G loss: 0.8736]
# [Epoch 16/50] [Batch 600/1950] [D loss: 0.6696] [G loss: 0.8522]
# [Epoch 16/50] [Batch 700/1950] [D loss: 0.6716] [G loss: 0.8727]
# [Epoch 16/50] [Batch 800/1950] [D loss: 0.6523] [G loss: 0.8373]
# [Epoch 16/50] [Batch 900/1950] [D loss: 0.6647] [G loss: 0.8928]
# [Epoch 16/50] [Batch 1000/1950] [D loss: 0.6715] [G loss: 0.8504]
# [Epoch 16/50] [Batch 1100/1950] [D loss: 0.6732] [G loss: 0.8759]
# [Epoch 16/50] [Batch 1200/1950] [D loss: 0.6557] [G loss: 0.8561]
# [Epoch 16/50] [Batch 1300/1950] [D loss: 0.6603] [G loss: 0.8432]
# [Epoch 16/50] [Batch 1400/1950] [D loss: 0.6752] [G loss: 0.8848]
# [Epoch 16/50] [Batch 1500/1950] [D loss: 0.6679] [G loss: 0.8789]
# [Epoch 16/50] [Batch 1600/1950] [D loss: 0.6689] [G loss: 0.8701]
# [Epoch 16/50] [Batch 1700/1950] [D loss: 0.6852] [G loss: 0.8697]
# [Epoch 16/50] [Batch 1800/1950] [D loss: 0.6678] [G loss: 0.8680]
# [Epoch 16/50] [Batch 1900/1950] [D loss: 0.6690] [G loss: 0.9051]
# [Epoch 17/50] [Batch 0/1950] [D loss: 0.6524] [G loss: 0.8586]
# [Epoch 17/50] [Batch 100/1950] [D loss: 0.6664] [G loss: 0.8814]
# [Epoch 17/50] [Batch 200/1950] [D loss: 0.6690] [G loss: 0.8962]
# [Epoch 17/50] [Batch 300/1950] [D loss: 0.6564] [G loss: 0.8765]
# [Epoch 17/50] [Batch 400/1950] [D loss: 0.6779] [G loss: 0.9043]
# [Epoch 17/50] [Batch 500/1950] [D loss: 0.6778] [G loss: 0.8739]
# [Epoch 17/50] [Batch 600/1950] [D loss: 0.6601] [G loss: 0.8846]
# [Epoch 17/50] [Batch 700/1950] [D loss: 0.6521] [G loss: 0.8768]
# [Epoch 17/50] [Batch 800/1950] [D loss: 0.6661] [G loss: 0.8609]
# [Epoch 17/50] [Batch 900/1950] [D loss: 0.6697] [G loss: 0.8770]
# [Epoch 17/50] [Batch 1000/1950] [D loss: 0.6593] [G loss: 0.8715]
# [Epoch 17/50] [Batch 1100/1950] [D loss: 0.6378] [G loss: 0.8508]
# [Epoch 17/50] [Batch 1200/1950] [D loss: 0.6940] [G loss: 0.8369]
# [Epoch 17/50] [Batch 1300/1950] [D loss: 0.6707] [G loss: 0.9114]
# [Epoch 17/50] [Batch 1400/1950] [D loss: 0.6810] [G loss: 0.8808]
# [Epoch 17/50] [Batch 1500/1950] [D loss: 0.6971] [G loss: 0.8955]
# [Epoch 17/50] [Batch 1600/1950] [D loss: 0.6604] [G loss: 0.8710]
# [Epoch 17/50] [Batch 1700/1950] [D loss: 0.6620] [G loss: 0.8664]
# [Epoch 17/50] [Batch 1800/1950] [D loss: 0.6832] [G loss: 0.8594]
# [Epoch 17/50] [Batch 1900/1950] [D loss: 0.6703] [G loss: 0.8979]
# [Epoch 18/50] [Batch 0/1950] [D loss: 0.6740] [G loss: 0.8654]
# [Epoch 18/50] [Batch 100/1950] [D loss: 0.6548] [G loss: 0.8802]
# [Epoch 18/50] [Batch 200/1950] [D loss: 0.6719] [G loss: 0.8804]
# [Epoch 18/50] [Batch 300/1950] [D loss: 0.6610] [G loss: 0.8641]
# [Epoch 18/50] [Batch 400/1950] [D loss: 0.6501] [G loss: 0.8369]
# [Epoch 18/50] [Batch 500/1950] [D loss: 0.6730] [G loss: 0.8313]
# [Epoch 18/50] [Batch 600/1950] [D loss: 0.6577] [G loss: 0.8464]
# [Epoch 18/50] [Batch 700/1950] [D loss: 0.6623] [G loss: 0.8459]
# [Epoch 18/50] [Batch 800/1950] [D loss: 0.6704] [G loss: 0.8657]
# [Epoch 18/50] [Batch 900/1950] [D loss: 0.6585] [G loss: 0.8618]
# [Epoch 18/50] [Batch 1000/1950] [D loss: 0.6683] [G loss: 0.8729]
# [Epoch 18/50] [Batch 1100/1950] [D loss: 0.6786] [G loss: 0.8382]
# [Epoch 18/50] [Batch 1200/1950] [D loss: 0.6608] [G loss: 0.8614]
# [Epoch 18/50] [Batch 1300/1950] [D loss: 0.6654] [G loss: 0.8682]
# [Epoch 18/50] [Batch 1400/1950] [D loss: 0.6666] [G loss: 0.8548]
# [Epoch 18/50] [Batch 1500/1950] [D loss: 0.6841] [G loss: 0.8690]
# [Epoch 18/50] [Batch 1600/1950] [D loss: 0.6769] [G loss: 0.8706]
# [Epoch 18/50] [Batch 1700/1950] [D loss: 0.6702] [G loss: 0.8875]
# [Epoch 18/50] [Batch 1800/1950] [D loss: 0.6733] [G loss: 0.8564]
# [Epoch 18/50] [Batch 1900/1950] [D loss: 0.6482] [G loss: 0.8668]
# [Epoch 19/50] [Batch 0/1950] [D loss: 0.6761] [G loss: 0.8798]
# [Epoch 19/50] [Batch 100/1950] [D loss: 0.6765] [G loss: 0.8475]
# [Epoch 19/50] [Batch 200/1950] [D loss: 0.6746] [G loss: 0.8782]
# [Epoch 19/50] [Batch 300/1950] [D loss: 0.6848] [G loss: 0.8727]
# [Epoch 19/50] [Batch 400/1950] [D loss: 0.6494] [G loss: 0.8535]
# [Epoch 19/50] [Batch 500/1950] [D loss: 0.6530] [G loss: 0.8854]
# [Epoch 19/50] [Batch 600/1950] [D loss: 0.6666] [G loss: 0.8744]
# [Epoch 19/50] [Batch 700/1950] [D loss: 0.6680] [G loss: 0.8669]
# [Epoch 19/50] [Batch 800/1950] [D loss: 0.6709] [G loss: 0.8690]
# [Epoch 19/50] [Batch 900/1950] [D loss: 0.6517] [G loss: 0.8702]
# [Epoch 19/50] [Batch 1000/1950] [D loss: 0.6564] [G loss: 0.8608]
# [Epoch 19/50] [Batch 1100/1950] [D loss: 0.6472] [G loss: 0.8668]
# [Epoch 19/50] [Batch 1200/1950] [D loss: 0.6627] [G loss: 0.8735]
# [Epoch 19/50] [Batch 1300/1950] [D loss: 0.6736] [G loss: 0.8880]
# [Epoch 19/50] [Batch 1400/1950] [D loss: 0.6497] [G loss: 0.8785]
# [Epoch 19/50] [Batch 1500/1950] [D loss: 0.6797] [G loss: 0.8695]
# [Epoch 19/50] [Batch 1600/1950] [D loss: 0.6591] [G loss: 0.8911]
# [Epoch 19/50] [Batch 1700/1950] [D loss: 0.6750] [G loss: 0.8849]
# [Epoch 19/50] [Batch 1800/1950] [D loss: 0.6718] [G loss: 0.8544]
# [Epoch 19/50] [Batch 1900/1950] [D loss: 0.6835] [G loss: 0.8898]
# [Epoch 20/50] [Batch 0/1950] [D loss: 0.6532] [G loss: 0.8655]
# [Epoch 20/50] [Batch 100/1950] [D loss: 0.6553] [G loss: 0.8405]
# [Epoch 20/50] [Batch 200/1950] [D loss: 0.6669] [G loss: 0.8358]
# [Epoch 20/50] [Batch 300/1950] [D loss: 0.6595] [G loss: 0.8681]
# [Epoch 20/50] [Batch 400/1950] [D loss: 0.6893] [G loss: 0.9007]
# [Epoch 20/50] [Batch 500/1950] [D loss: 0.6636] [G loss: 0.8452]
# [Epoch 20/50] [Batch 600/1950] [D loss: 0.6433] [G loss: 0.9051]
# [Epoch 20/50] [Batch 700/1950] [D loss: 0.6570] [G loss: 0.8182]
# [Epoch 20/50] [Batch 800/1950] [D loss: 0.6661] [G loss: 0.8514]
# [Epoch 20/50] [Batch 900/1950] [D loss: 0.6407] [G loss: 0.8754]
# [Epoch 20/50] [Batch 1000/1950] [D loss: 0.6664] [G loss: 0.8379]
# [Epoch 20/50] [Batch 1100/1950] [D loss: 0.6642] [G loss: 0.8812]
# [Epoch 20/50] [Batch 1200/1950] [D loss: 0.6576] [G loss: 0.8283]
# [Epoch 20/50] [Batch 1300/1950] [D loss: 0.6611] [G loss: 0.8521]
# [Epoch 20/50] [Batch 1400/1950] [D loss: 0.6791] [G loss: 0.9304]
# [Epoch 20/50] [Batch 1500/1950] [D loss: 0.6555] [G loss: 0.8465]
# [Epoch 20/50] [Batch 1600/1950] [D loss: 0.6722] [G loss: 0.8850]
# [Epoch 20/50] [Batch 1700/1950] [D loss: 0.6591] [G loss: 0.8360]
# [Epoch 20/50] [Batch 1800/1950] [D loss: 0.6417] [G loss: 0.8703]
# [Epoch 20/50] [Batch 1900/1950] [D loss: 0.6696] [G loss: 0.8260]
# [Epoch 21/50] [Batch 0/1950] [D loss: 0.6756] [G loss: 0.8322]
# [Epoch 21/50] [Batch 100/1950] [D loss: 0.6579] [G loss: 0.8661]
# [Epoch 21/50] [Batch 200/1950] [D loss: 0.6507] [G loss: 0.8988]
# [Epoch 21/50] [Batch 300/1950] [D loss: 0.6649] [G loss: 0.8509]
# [Epoch 21/50] [Batch 400/1950] [D loss: 0.6630] [G loss: 0.8956]
# [Epoch 21/50] [Batch 500/1950] [D loss: 0.6717] [G loss: 0.9218]
# [Epoch 21/50] [Batch 600/1950] [D loss: 0.6714] [G loss: 0.8626]
# [Epoch 21/50] [Batch 700/1950] [D loss: 0.6649] [G loss: 0.8436]
# [Epoch 21/50] [Batch 800/1950] [D loss: 0.6492] [G loss: 0.8612]
# [Epoch 21/50] [Batch 900/1950] [D loss: 0.6776] [G loss: 0.8818]
# [Epoch 21/50] [Batch 1000/1950] [D loss: 0.6513] [G loss: 0.8971]
# [Epoch 21/50] [Batch 1100/1950] [D loss: 0.6565] [G loss: 0.8735]
# [Epoch 21/50] [Batch 1200/1950] [D loss: 0.6532] [G loss: 0.8276]
# [Epoch 21/50] [Batch 1300/1950] [D loss: 0.6549] [G loss: 0.8715]
# [Epoch 21/50] [Batch 1400/1950] [D loss: 0.6576] [G loss: 0.8541]
# [Epoch 21/50] [Batch 1500/1950] [D loss: 0.6668] [G loss: 0.8750]
# [Epoch 21/50] [Batch 1600/1950] [D loss: 0.6630] [G loss: 0.9008]
# [Epoch 21/50] [Batch 1700/1950] [D loss: 0.6838] [G loss: 0.8748]
# [Epoch 21/50] [Batch 1800/1950] [D loss: 0.6819] [G loss: 0.8799]
# [Epoch 21/50] [Batch 1900/1950] [D loss: 0.6440] [G loss: 0.8757]
# [Epoch 22/50] [Batch 0/1950] [D loss: 0.6716] [G loss: 0.9019]
# [Epoch 22/50] [Batch 100/1950] [D loss: 0.6525] [G loss: 0.8510]
# [Epoch 22/50] [Batch 200/1950] [D loss: 0.6656] [G loss: 0.9015]
# [Epoch 22/50] [Batch 300/1950] [D loss: 0.6779] [G loss: 0.8693]
# [Epoch 22/50] [Batch 400/1950] [D loss: 0.6693] [G loss: 0.8856]
# [Epoch 22/50] [Batch 500/1950] [D loss: 0.6519] [G loss: 0.8589]
# [Epoch 22/50] [Batch 600/1950] [D loss: 0.6617] [G loss: 0.8646]
# [Epoch 22/50] [Batch 700/1950] [D loss: 0.6721] [G loss: 0.8621]
# [Epoch 22/50] [Batch 800/1950] [D loss: 0.6531] [G loss: 0.8728]
# [Epoch 22/50] [Batch 900/1950] [D loss: 0.6653] [G loss: 0.8675]
# [Epoch 22/50] [Batch 1000/1950] [D loss: 0.6721] [G loss: 0.8883]
# [Epoch 22/50] [Batch 1100/1950] [D loss: 0.6781] [G loss: 0.8626]
# [Epoch 22/50] [Batch 1200/1950] [D loss: 0.6618] [G loss: 0.8216]
# [Epoch 22/50] [Batch 1300/1950] [D loss: 0.6525] [G loss: 0.8489]
# [Epoch 22/50] [Batch 1400/1950] [D loss: 0.6399] [G loss: 0.8608]
# [Epoch 22/50] [Batch 1500/1950] [D loss: 0.6701] [G loss: 0.8743]
# [Epoch 22/50] [Batch 1600/1950] [D loss: 0.6368] [G loss: 0.8751]
# [Epoch 22/50] [Batch 1700/1950] [D loss: 0.6483] [G loss: 0.8432]
# [Epoch 22/50] [Batch 1800/1950] [D loss: 0.6719] [G loss: 0.8813]
# [Epoch 22/50] [Batch 1900/1950] [D loss: 0.6588] [G loss: 0.8987]
# [Epoch 23/50] [Batch 0/1950] [D loss: 0.6946] [G loss: 0.8535]
# [Epoch 23/50] [Batch 100/1950] [D loss: 0.6745] [G loss: 0.8653]
# [Epoch 23/50] [Batch 200/1950] [D loss: 0.6677] [G loss: 0.8703]
# [Epoch 23/50] [Batch 300/1950] [D loss: 0.6534] [G loss: 0.8831]
# [Epoch 23/50] [Batch 400/1950] [D loss: 0.6878] [G loss: 0.8855]
# [Epoch 23/50] [Batch 500/1950] [D loss: 0.6604] [G loss: 0.8783]
# [Epoch 23/50] [Batch 600/1950] [D loss: 0.6546] [G loss: 0.8783]
# [Epoch 23/50] [Batch 700/1950] [D loss: 0.6717] [G loss: 0.8632]
# [Epoch 23/50] [Batch 800/1950] [D loss: 0.6503] [G loss: 0.8559]
# [Epoch 23/50] [Batch 900/1950] [D loss: 0.6772] [G loss: 0.8910]
# [Epoch 23/50] [Batch 1000/1950] [D loss: 0.6773] [G loss: 0.8682]
# [Epoch 23/50] [Batch 1100/1950] [D loss: 0.6745] [G loss: 0.8445]
# [Epoch 23/50] [Batch 1200/1950] [D loss: 0.6695] [G loss: 0.8732]
# [Epoch 23/50] [Batch 1300/1950] [D loss: 0.6861] [G loss: 0.8725]
# [Epoch 23/50] [Batch 1400/1950] [D loss: 0.6755] [G loss: 0.8952]
# [Epoch 23/50] [Batch 1500/1950] [D loss: 0.6629] [G loss: 0.8295]
# [Epoch 23/50] [Batch 1600/1950] [D loss: 0.6747] [G loss: 0.8879]
# [Epoch 23/50] [Batch 1700/1950] [D loss: 0.6793] [G loss: 0.8730]
# [Epoch 23/50] [Batch 1800/1950] [D loss: 0.6403] [G loss: 0.8460]
# [Epoch 23/50] [Batch 1900/1950] [D loss: 0.6591] [G loss: 0.8807]
# [Epoch 24/50] [Batch 0/1950] [D loss: 0.6846] [G loss: 0.8569]
# [Epoch 24/50] [Batch 100/1950] [D loss: 0.6733] [G loss: 0.8387]
# [Epoch 24/50] [Batch 200/1950] [D loss: 0.6614] [G loss: 0.8867]
# [Epoch 24/50] [Batch 300/1950] [D loss: 0.6628] [G loss: 0.8676]
# [Epoch 24/50] [Batch 400/1950] [D loss: 0.6573] [G loss: 0.9048]
# [Epoch 24/50] [Batch 500/1950] [D loss: 0.6712] [G loss: 0.8790]
# [Epoch 24/50] [Batch 600/1950] [D loss: 0.6778] [G loss: 0.8733]
# [Epoch 24/50] [Batch 700/1950] [D loss: 0.6564] [G loss: 0.8867]
# [Epoch 24/50] [Batch 800/1950] [D loss: 0.6534] [G loss: 0.9239]
# [Epoch 24/50] [Batch 900/1950] [D loss: 0.6830] [G loss: 0.8956]
# [Epoch 24/50] [Batch 1000/1950] [D loss: 0.6673] [G loss: 0.8672]
# [Epoch 24/50] [Batch 1100/1950] [D loss: 0.6667] [G loss: 0.8479]
# [Epoch 24/50] [Batch 1200/1950] [D loss: 0.6707] [G loss: 0.8151]
# [Epoch 24/50] [Batch 1300/1950] [D loss: 0.6790] [G loss: 0.8496]
# [Epoch 24/50] [Batch 1400/1950] [D loss: 0.6935] [G loss: 0.8835]
# [Epoch 24/50] [Batch 1500/1950] [D loss: 0.6679] [G loss: 0.8701]
# [Epoch 24/50] [Batch 1600/1950] [D loss: 0.6640] [G loss: 0.8719]
# [Epoch 24/50] [Batch 1700/1950] [D loss: 0.6791] [G loss: 0.8501]
# [Epoch 24/50] [Batch 1800/1950] [D loss: 0.6788] [G loss: 0.8667]
# [Epoch 24/50] [Batch 1900/1950] [D loss: 0.6579] [G loss: 0.8746]
# [Epoch 25/50] [Batch 0/1950] [D loss: 0.6784] [G loss: 0.8669]
# [Epoch 25/50] [Batch 100/1950] [D loss: 0.6593] [G loss: 0.8523]
# [Epoch 25/50] [Batch 200/1950] [D loss: 0.6606] [G loss: 0.8701]
# [Epoch 25/50] [Batch 300/1950] [D loss: 0.6651] [G loss: 0.9074]
# [Epoch 25/50] [Batch 400/1950] [D loss: 0.6519] [G loss: 0.8519]
# [Epoch 25/50] [Batch 500/1950] [D loss: 0.6572] [G loss: 0.8870]
# [Epoch 25/50] [Batch 600/1950] [D loss: 0.6406] [G loss: 0.8301]
# [Epoch 25/50] [Batch 700/1950] [D loss: 0.6671] [G loss: 0.8369]
# [Epoch 25/50] [Batch 800/1950] [D loss: 0.6762] [G loss: 0.8717]
# [Epoch 25/50] [Batch 900/1950] [D loss: 0.6569] [G loss: 0.8514]
# [Epoch 25/50] [Batch 1000/1950] [D loss: 0.6681] [G loss: 0.8602]
# [Epoch 25/50] [Batch 1100/1950] [D loss: 0.6604] [G loss: 0.8898]
# [Epoch 25/50] [Batch 1200/1950] [D loss: 0.6598] [G loss: 0.8671]
# [Epoch 25/50] [Batch 1300/1950] [D loss: 0.6728] [G loss: 0.8843]
# [Epoch 25/50] [Batch 1400/1950] [D loss: 0.6956] [G loss: 0.8273]
# [Epoch 25/50] [Batch 1500/1950] [D loss: 0.6594] [G loss: 0.8676]
# [Epoch 25/50] [Batch 1600/1950] [D loss: 0.6613] [G loss: 0.8848]
# [Epoch 25/50] [Batch 1700/1950] [D loss: 0.6825] [G loss: 0.8826]
# [Epoch 25/50] [Batch 1800/1950] [D loss: 0.6445] [G loss: 0.8549]
# [Epoch 25/50] [Batch 1900/1950] [D loss: 0.6567] [G loss: 0.8621]
# [Epoch 26/50] [Batch 0/1950] [D loss: 0.6604] [G loss: 0.8560]
# [Epoch 26/50] [Batch 100/1950] [D loss: 0.6659] [G loss: 0.8824]
# [Epoch 26/50] [Batch 200/1950] [D loss: 0.6795] [G loss: 0.9044]
# [Epoch 26/50] [Batch 300/1950] [D loss: 0.6586] [G loss: 0.8483]
# [Epoch 26/50] [Batch 400/1950] [D loss: 0.6539] [G loss: 0.8655]
# [Epoch 26/50] [Batch 500/1950] [D loss: 0.6902] [G loss: 0.8569]
# [Epoch 26/50] [Batch 600/1950] [D loss: 0.6648] [G loss: 0.8771]
# [Epoch 26/50] [Batch 700/1950] [D loss: 0.6561] [G loss: 0.8945]
# [Epoch 26/50] [Batch 800/1950] [D loss: 0.6677] [G loss: 0.8647]
# [Epoch 26/50] [Batch 900/1950] [D loss: 0.6860] [G loss: 0.8613]
# [Epoch 26/50] [Batch 1000/1950] [D loss: 0.6794] [G loss: 0.8655]
# [Epoch 26/50] [Batch 1100/1950] [D loss: 0.6611] [G loss: 0.8353]
# [Epoch 26/50] [Batch 1200/1950] [D loss: 0.6669] [G loss: 0.8559]
# [Epoch 26/50] [Batch 1300/1950] [D loss: 0.6575] [G loss: 0.8706]
# [Epoch 26/50] [Batch 1400/1950] [D loss: 0.6644] [G loss: 0.8510]
# [Epoch 26/50] [Batch 1500/1950] [D loss: 0.6764] [G loss: 0.8630]
# [Epoch 26/50] [Batch 1600/1950] [D loss: 0.6787] [G loss: 0.8898]
# [Epoch 26/50] [Batch 1700/1950] [D loss: 0.6745] [G loss: 0.8499]
# [Epoch 26/50] [Batch 1800/1950] [D loss: 0.6492] [G loss: 0.8870]
# [Epoch 26/50] [Batch 1900/1950] [D loss: 0.6705] [G loss: 0.8605]
# [Epoch 27/50] [Batch 0/1950] [D loss: 0.6526] [G loss: 0.8647]
# [Epoch 27/50] [Batch 100/1950] [D loss: 0.6682] [G loss: 0.8722]
# [Epoch 27/50] [Batch 200/1950] [D loss: 0.6671] [G loss: 0.8876]
# [Epoch 27/50] [Batch 300/1950] [D loss: 0.6532] [G loss: 0.8349]
# [Epoch 27/50] [Batch 400/1950] [D loss: 0.6470] [G loss: 0.8772]
# [Epoch 27/50] [Batch 500/1950] [D loss: 0.6548] [G loss: 0.8685]
# [Epoch 27/50] [Batch 600/1950] [D loss: 0.6544] [G loss: 0.8393]
# [Epoch 27/50] [Batch 700/1950] [D loss: 0.6623] [G loss: 0.9004]
# [Epoch 27/50] [Batch 800/1950] [D loss: 0.6416] [G loss: 0.8466]
# [Epoch 27/50] [Batch 900/1950] [D loss: 0.6661] [G loss: 0.8505]
# [Epoch 27/50] [Batch 1000/1950] [D loss: 0.6577] [G loss: 0.9248]
# [Epoch 27/50] [Batch 1100/1950] [D loss: 0.6609] [G loss: 0.8698]
# [Epoch 27/50] [Batch 1200/1950] [D loss: 0.6568] [G loss: 0.8579]
# [Epoch 27/50] [Batch 1300/1950] [D loss: 0.6599] [G loss: 0.8707]
# [Epoch 27/50] [Batch 1400/1950] [D loss: 0.6461] [G loss: 0.8702]
# [Epoch 27/50] [Batch 1500/1950] [D loss: 0.6606] [G loss: 0.8485]
# [Epoch 27/50] [Batch 1600/1950] [D loss: 0.6691] [G loss: 0.8361]
# [Epoch 27/50] [Batch 1700/1950] [D loss: 0.6698] [G loss: 0.8528]
# [Epoch 27/50] [Batch 1800/1950] [D loss: 0.6607] [G loss: 0.8631]
# [Epoch 27/50] [Batch 1900/1950] [D loss: 0.6559] [G loss: 0.8535]
# [Epoch 28/50] [Batch 0/1950] [D loss: 0.6513] [G loss: 0.8263]
# [Epoch 28/50] [Batch 100/1950] [D loss: 0.6748] [G loss: 0.8379]
# [Epoch 28/50] [Batch 200/1950] [D loss: 0.6796] [G loss: 0.8767]
# [Epoch 28/50] [Batch 300/1950] [D loss: 0.6661] [G loss: 0.8526]
# [Epoch 28/50] [Batch 400/1950] [D loss: 0.6882] [G loss: 0.8886]
# [Epoch 28/50] [Batch 500/1950] [D loss: 0.6709] [G loss: 0.8986]
# [Epoch 28/50] [Batch 600/1950] [D loss: 0.6613] [G loss: 0.8850]
# [Epoch 28/50] [Batch 700/1950] [D loss: 0.6676] [G loss: 0.8525]
# [Epoch 28/50] [Batch 800/1950] [D loss: 0.6613] [G loss: 0.9043]
# [Epoch 28/50] [Batch 900/1950] [D loss: 0.6684] [G loss: 0.8385]
# [Epoch 28/50] [Batch 1000/1950] [D loss: 0.6669] [G loss: 0.8815]
# [Epoch 28/50] [Batch 1100/1950] [D loss: 0.6682] [G loss: 0.8543]
# [Epoch 28/50] [Batch 1200/1950] [D loss: 0.6333] [G loss: 0.8825]
# [Epoch 28/50] [Batch 1300/1950] [D loss: 0.6513] [G loss: 0.8455]
# [Epoch 28/50] [Batch 1400/1950] [D loss: 0.6637] [G loss: 0.8697]
# [Epoch 28/50] [Batch 1500/1950] [D loss: 0.6524] [G loss: 0.8583]
# [Epoch 28/50] [Batch 1600/1950] [D loss: 0.6689] [G loss: 0.8996]
# [Epoch 28/50] [Batch 1700/1950] [D loss: 0.6732] [G loss: 0.8744]
# [Epoch 28/50] [Batch 1800/1950] [D loss: 0.6564] [G loss: 0.8656]
# [Epoch 28/50] [Batch 1900/1950] [D loss: 0.6516] [G loss: 0.8612]
# [Epoch 29/50] [Batch 0/1950] [D loss: 0.6658] [G loss: 0.8408]
# [Epoch 29/50] [Batch 100/1950] [D loss: 0.6800] [G loss: 0.8554]
# [Epoch 29/50] [Batch 200/1950] [D loss: 0.6315] [G loss: 0.8530]
# [Epoch 29/50] [Batch 300/1950] [D loss: 0.6836] [G loss: 0.8975]
# [Epoch 29/50] [Batch 400/1950] [D loss: 0.6709] [G loss: 0.8881]
# [Epoch 29/50] [Batch 500/1950] [D loss: 0.6499] [G loss: 0.8976]
# [Epoch 29/50] [Batch 600/1950] [D loss: 0.6603] [G loss: 0.8664]
# [Epoch 29/50] [Batch 700/1950] [D loss: 0.6549] [G loss: 0.8684]
# [Epoch 29/50] [Batch 800/1950] [D loss: 0.6619] [G loss: 0.8666]
# [Epoch 29/50] [Batch 900/1950] [D loss: 0.6501] [G loss: 0.8873]
# [Epoch 29/50] [Batch 1000/1950] [D loss: 0.6848] [G loss: 0.8618]
# [Epoch 29/50] [Batch 1100/1950] [D loss: 0.6602] [G loss: 0.9034]
# [Epoch 29/50] [Batch 1200/1950] [D loss: 0.6597] [G loss: 0.8759]
# [Epoch 29/50] [Batch 1300/1950] [D loss: 0.6498] [G loss: 0.8296]
# [Epoch 29/50] [Batch 1400/1950] [D loss: 0.6621] [G loss: 0.8384]
# [Epoch 29/50] [Batch 1500/1950] [D loss: 0.6670] [G loss: 0.8703]
# [Epoch 29/50] [Batch 1600/1950] [D loss: 0.6685] [G loss: 0.8613]
# [Epoch 29/50] [Batch 1700/1950] [D loss: 0.7041] [G loss: 0.8763]
# [Epoch 29/50] [Batch 1800/1950] [D loss: 0.6588] [G loss: 0.8518]
# [Epoch 29/50] [Batch 1900/1950] [D loss: 0.6587] [G loss: 0.8701]
# [Epoch 30/50] [Batch 0/1950] [D loss: 0.6570] [G loss: 0.8695]
# [Epoch 30/50] [Batch 100/1950] [D loss: 0.6613] [G loss: 0.8738]
# [Epoch 30/50] [Batch 200/1950] [D loss: 0.6679] [G loss: 0.8889]
# [Epoch 30/50] [Batch 300/1950] [D loss: 0.6502] [G loss: 0.8604]
# [Epoch 30/50] [Batch 400/1950] [D loss: 0.6694] [G loss: 0.8675]
# [Epoch 30/50] [Batch 500/1950] [D loss: 0.6781] [G loss: 0.8983]
# [Epoch 30/50] [Batch 600/1950] [D loss: 0.6675] [G loss: 0.8869]
# [Epoch 30/50] [Batch 700/1950] [D loss: 0.6803] [G loss: 0.8501]
# [Epoch 30/50] [Batch 800/1950] [D loss: 0.6695] [G loss: 0.8668]
# [Epoch 30/50] [Batch 900/1950] [D loss: 0.6481] [G loss: 0.8776]
# [Epoch 30/50] [Batch 1000/1950] [D loss: 0.6785] [G loss: 0.8383]
# [Epoch 30/50] [Batch 1100/1950] [D loss: 0.6678] [G loss: 0.8220]
# [Epoch 30/50] [Batch 1200/1950] [D loss: 0.6596] [G loss: 0.9039]
# [Epoch 30/50] [Batch 1300/1950] [D loss: 0.6847] [G loss: 0.8786]
# [Epoch 30/50] [Batch 1400/1950] [D loss: 0.6762] [G loss: 0.9247]
# [Epoch 30/50] [Batch 1500/1950] [D loss: 0.6297] [G loss: 0.8394]
# [Epoch 30/50] [Batch 1600/1950] [D loss: 0.6616] [G loss: 0.8633]
# [Epoch 30/50] [Batch 1700/1950] [D loss: 0.6560] [G loss: 0.8854]
# [Epoch 30/50] [Batch 1800/1950] [D loss: 0.6561] [G loss: 0.9045]
# [Epoch 30/50] [Batch 1900/1950] [D loss: 0.6508] [G loss: 0.8631]
# [Epoch 31/50] [Batch 0/1950] [D loss: 0.6690] [G loss: 0.8402]
# [Epoch 31/50] [Batch 100/1950] [D loss: 0.6525] [G loss: 0.8777]
# [Epoch 31/50] [Batch 200/1950] [D loss: 0.6419] [G loss: 0.8371]
# [Epoch 31/50] [Batch 300/1950] [D loss: 0.6633] [G loss: 0.8616]
# [Epoch 31/50] [Batch 400/1950] [D loss: 0.6604] [G loss: 0.8849]
# [Epoch 31/50] [Batch 500/1950] [D loss: 0.6623] [G loss: 0.8291]
# [Epoch 31/50] [Batch 600/1950] [D loss: 0.6718] [G loss: 0.8684]
# [Epoch 31/50] [Batch 700/1950] [D loss: 0.6321] [G loss: 0.8589]
# [Epoch 31/50] [Batch 800/1950] [D loss: 0.6526] [G loss: 0.8490]
# [Epoch 31/50] [Batch 900/1950] [D loss: 0.6618] [G loss: 0.8748]
# [Epoch 31/50] [Batch 1000/1950] [D loss: 0.6619] [G loss: 0.8717]
# [Epoch 31/50] [Batch 1100/1950] [D loss: 0.6818] [G loss: 0.8829]
# [Epoch 31/50] [Batch 1200/1950] [D loss: 0.6492] [G loss: 0.8946]
# [Epoch 31/50] [Batch 1300/1950] [D loss: 0.6633] [G loss: 0.8869]
# [Epoch 31/50] [Batch 1400/1950] [D loss: 0.6535] [G loss: 0.8512]
# [Epoch 31/50] [Batch 1500/1950] [D loss: 0.6594] [G loss: 0.8717]
# [Epoch 31/50] [Batch 1600/1950] [D loss: 0.6536] [G loss: 0.8777]
# [Epoch 31/50] [Batch 1700/1950] [D loss: 0.6695] [G loss: 0.8903]
# [Epoch 31/50] [Batch 1800/1950] [D loss: 0.6668] [G loss: 0.8680]
# [Epoch 31/50] [Batch 1900/1950] [D loss: 0.6441] [G loss: 0.8694]
# [Epoch 32/50] [Batch 0/1950] [D loss: 0.6588] [G loss: 0.8548]
# [Epoch 32/50] [Batch 100/1950] [D loss: 0.6764] [G loss: 0.8778]
# [Epoch 32/50] [Batch 200/1950] [D loss: 0.6527] [G loss: 0.8954]
# [Epoch 32/50] [Batch 300/1950] [D loss: 0.6724] [G loss: 0.8904]
# [Epoch 32/50] [Batch 400/1950] [D loss: 0.6866] [G loss: 0.9017]
# [Epoch 32/50] [Batch 500/1950] [D loss: 0.6752] [G loss: 0.9174]
# [Epoch 32/50] [Batch 600/1950] [D loss: 0.6870] [G loss: 0.8929]
# [Epoch 32/50] [Batch 700/1950] [D loss: 0.6493] [G loss: 0.8420]
# [Epoch 32/50] [Batch 800/1950] [D loss: 0.6574] [G loss: 0.8758]
# [Epoch 32/50] [Batch 900/1950] [D loss: 0.6579] [G loss: 0.8461]
# [Epoch 32/50] [Batch 1000/1950] [D loss: 0.6801] [G loss: 0.8742]
# [Epoch 32/50] [Batch 1100/1950] [D loss: 0.6816] [G loss: 0.8627]
# [Epoch 32/50] [Batch 1200/1950] [D loss: 0.6589] [G loss: 0.8914]
# [Epoch 32/50] [Batch 1300/1950] [D loss: 0.6627] [G loss: 0.8793]
# [Epoch 32/50] [Batch 1400/1950] [D loss: 0.6648] [G loss: 0.8603]
# [Epoch 32/50] [Batch 1500/1950] [D loss: 0.6736] [G loss: 0.8842]
# [Epoch 32/50] [Batch 1600/1950] [D loss: 0.6919] [G loss: 0.8740]
# [Epoch 32/50] [Batch 1700/1950] [D loss: 0.6669] [G loss: 0.8827]
# [Epoch 32/50] [Batch 1800/1950] [D loss: 0.6597] [G loss: 0.8815]
# [Epoch 32/50] [Batch 1900/1950] [D loss: 0.6427] [G loss: 0.8303]
# [Epoch 33/50] [Batch 0/1950] [D loss: 0.6480] [G loss: 0.8858]
# [Epoch 33/50] [Batch 100/1950] [D loss: 0.6577] [G loss: 0.8434]
# [Epoch 33/50] [Batch 200/1950] [D loss: 0.6443] [G loss: 0.8953]
# [Epoch 33/50] [Batch 300/1950] [D loss: 0.6488] [G loss: 0.8716]
# [Epoch 33/50] [Batch 400/1950] [D loss: 0.6580] [G loss: 0.8425]
# [Epoch 33/50] [Batch 500/1950] [D loss: 0.6779] [G loss: 0.8831]
# [Epoch 33/50] [Batch 600/1950] [D loss: 0.6700] [G loss: 0.8734]
# [Epoch 33/50] [Batch 700/1950] [D loss: 0.6564] [G loss: 0.9046]
# [Epoch 33/50] [Batch 800/1950] [D loss: 0.6477] [G loss: 0.8397]
# [Epoch 33/50] [Batch 900/1950] [D loss: 0.6638] [G loss: 0.9024]
# [Epoch 33/50] [Batch 1000/1950] [D loss: 0.6715] [G loss: 0.8760]
# [Epoch 33/50] [Batch 1100/1950] [D loss: 0.6574] [G loss: 0.8374]
# [Epoch 33/50] [Batch 1200/1950] [D loss: 0.6864] [G loss: 0.8674]
# [Epoch 33/50] [Batch 1300/1950] [D loss: 0.6417] [G loss: 0.8692]
# [Epoch 33/50] [Batch 1400/1950] [D loss: 0.6568] [G loss: 0.8665]
# [Epoch 33/50] [Batch 1500/1950] [D loss: 0.6631] [G loss: 0.8752]
# [Epoch 33/50] [Batch 1600/1950] [D loss: 0.6612] [G loss: 0.8542]
# [Epoch 33/50] [Batch 1700/1950] [D loss: 0.6563] [G loss: 0.8927]
# [Epoch 33/50] [Batch 1800/1950] [D loss: 0.6997] [G loss: 0.8613]
# [Epoch 33/50] [Batch 1900/1950] [D loss: 0.6784] [G loss: 0.8714]
# [Epoch 34/50] [Batch 0/1950] [D loss: 0.6660] [G loss: 0.8389]
# [Epoch 34/50] [Batch 100/1950] [D loss: 0.6504] [G loss: 0.8476]
# [Epoch 34/50] [Batch 200/1950] [D loss: 0.6740] [G loss: 0.8890]
# [Epoch 34/50] [Batch 300/1950] [D loss: 0.6640] [G loss: 0.8641]
# [Epoch 34/50] [Batch 400/1950] [D loss: 0.6485] [G loss: 0.8397]
# [Epoch 34/50] [Batch 500/1950] [D loss: 0.6481] [G loss: 0.8857]
# [Epoch 34/50] [Batch 600/1950] [D loss: 0.6629] [G loss: 0.8771]
# [Epoch 34/50] [Batch 700/1950] [D loss: 0.6796] [G loss: 0.8672]
# [Epoch 34/50] [Batch 800/1950] [D loss: 0.6629] [G loss: 0.9084]
# [Epoch 34/50] [Batch 900/1950] [D loss: 0.6478] [G loss: 0.8276]
# [Epoch 34/50] [Batch 1000/1950] [D loss: 0.6802] [G loss: 0.9069]
# [Epoch 34/50] [Batch 1100/1950] [D loss: 0.6519] [G loss: 0.8757]
# [Epoch 34/50] [Batch 1200/1950] [D loss: 0.6654] [G loss: 0.8692]
# [Epoch 34/50] [Batch 1300/1950] [D loss: 0.6497] [G loss: 0.8217]
# [Epoch 34/50] [Batch 1400/1950] [D loss: 0.6382] [G loss: 0.8533]
# [Epoch 34/50] [Batch 1500/1950] [D loss: 0.6704] [G loss: 0.8666]
# [Epoch 34/50] [Batch 1600/1950] [D loss: 0.6652] [G loss: 0.8275]
# [Epoch 34/50] [Batch 1700/1950] [D loss: 0.6552] [G loss: 0.8844]
# [Epoch 34/50] [Batch 1800/1950] [D loss: 0.6787] [G loss: 0.8477]
# [Epoch 34/50] [Batch 1900/1950] [D loss: 0.6638] [G loss: 0.8956]
# [Epoch 35/50] [Batch 0/1950] [D loss: 0.6822] [G loss: 0.8906]
# [Epoch 35/50] [Batch 100/1950] [D loss: 0.6318] [G loss: 0.9166]
# [Epoch 35/50] [Batch 200/1950] [D loss: 0.6503] [G loss: 0.8760]
# [Epoch 35/50] [Batch 300/1950] [D loss: 0.6757] [G loss: 0.8993]
# [Epoch 35/50] [Batch 400/1950] [D loss: 0.6758] [G loss: 0.8687]
# [Epoch 35/50] [Batch 500/1950] [D loss: 0.6795] [G loss: 0.8457]
# [Epoch 35/50] [Batch 600/1950] [D loss: 0.6409] [G loss: 0.8742]
# [Epoch 35/50] [Batch 700/1950] [D loss: 0.6560] [G loss: 0.8622]
# [Epoch 35/50] [Batch 800/1950] [D loss: 0.6654] [G loss: 0.8283]
# [Epoch 35/50] [Batch 900/1950] [D loss: 0.6538] [G loss: 0.8444]
# [Epoch 35/50] [Batch 1000/1950] [D loss: 0.6535] [G loss: 0.8427]
# [Epoch 35/50] [Batch 1100/1950] [D loss: 0.6527] [G loss: 0.8881]
# [Epoch 35/50] [Batch 1200/1950] [D loss: 0.6372] [G loss: 0.8750]
# [Epoch 35/50] [Batch 1300/1950] [D loss: 0.6396] [G loss: 0.8707]
# [Epoch 35/50] [Batch 1400/1950] [D loss: 0.6897] [G loss: 0.9314]
# [Epoch 35/50] [Batch 1500/1950] [D loss: 0.6613] [G loss: 0.8496]
# [Epoch 35/50] [Batch 1600/1950] [D loss: 0.6507] [G loss: 0.9233]
# [Epoch 35/50] [Batch 1700/1950] [D loss: 0.6493] [G loss: 0.8531]
# [Epoch 35/50] [Batch 1800/1950] [D loss: 0.6669] [G loss: 0.8563]
# [Epoch 35/50] [Batch 1900/1950] [D loss: 0.6889] [G loss: 0.9132]
# [Epoch 36/50] [Batch 0/1950] [D loss: 0.6652] [G loss: 0.8740]
# [Epoch 36/50] [Batch 100/1950] [D loss: 0.6589] [G loss: 0.8352]
# [Epoch 36/50] [Batch 200/1950] [D loss: 0.6762] [G loss: 0.8729]
# [Epoch 36/50] [Batch 300/1950] [D loss: 0.6603] [G loss: 0.8222]
# [Epoch 36/50] [Batch 400/1950] [D loss: 0.6592] [G loss: 0.8685]
# [Epoch 36/50] [Batch 500/1950] [D loss: 0.6467] [G loss: 0.8656]
# [Epoch 36/50] [Batch 600/1950] [D loss: 0.6624] [G loss: 0.8784]
# [Epoch 36/50] [Batch 700/1950] [D loss: 0.6586] [G loss: 0.8296]
# [Epoch 36/50] [Batch 800/1950] [D loss: 0.6643] [G loss: 0.8755]
# [Epoch 36/50] [Batch 900/1950] [D loss: 0.6773] [G loss: 0.8947]
# [Epoch 36/50] [Batch 1000/1950] [D loss: 0.6915] [G loss: 0.8257]
# [Epoch 36/50] [Batch 1100/1950] [D loss: 0.6880] [G loss: 0.7975]
# [Epoch 36/50] [Batch 1200/1950] [D loss: 0.6720] [G loss: 0.8693]
# [Epoch 36/50] [Batch 1300/1950] [D loss: 0.6712] [G loss: 0.8792]
# [Epoch 36/50] [Batch 1400/1950] [D loss: 0.6529] [G loss: 0.8418]
# ...
# [Epoch 37/50] [Batch 1600/1950] [D loss: 0.6883] [G loss: 0.8980]
# [Epoch 37/50] [Batch 1700/1950] [D loss: 0.6626] [G loss: 0.8495]
# [Epoch 37/50] [Batch 1800/1950] [D loss: 0.6605] [G loss: 0.8606]
# [Epoch 37/50] [Batch 1900/1950] [D loss: 0.6644] [G loss: 0.8994]
# [Epoch 38/50] [Batch 0/1950] [D loss: 0.6637] [G loss: 0.8704]
# [Epoch 38/50] [Batch 100/1950] [D loss: 0.6605] [G loss: 0.8512]
# [Epoch 38/50] [Batch 200/1950] [D loss: 0.6629] [G loss: 0.9076]
# [Epoch 38/50] [Batch 300/1950] [D loss: 0.6715] [G loss: 0.9058]
# [Epoch 38/50] [Batch 400/1950] [D loss: 0.6542] [G loss: 0.9274]
# [Epoch 38/50] [Batch 500/1950] [D loss: 0.6639] [G loss: 0.9082]
# [Epoch 38/50] [Batch 600/1950] [D loss: 0.6501] [G loss: 0.8449]
# [Epoch 38/50] [Batch 700/1950] [D loss: 0.6688] [G loss: 0.8785]
# [Epoch 38/50] [Batch 800/1950] [D loss: 0.6567] [G loss: 0.8474]
# [Epoch 38/50] [Batch 900/1950] [D loss: 0.6646] [G loss: 0.8614]
# [Epoch 38/50] [Batch 1000/1950] [D loss: 0.6694] [G loss: 0.8680]
# [Epoch 38/50] [Batch 1100/1950] [D loss: 0.6630] [G loss: 0.9082]
# [Epoch 38/50] [Batch 1200/1950] [D loss: 0.6662] [G loss: 0.8901]
# [Epoch 38/50] [Batch 1300/1950] [D loss: 0.6607] [G loss: 0.8234]
# [Epoch 38/50] [Batch 1400/1950] [D loss: 0.6664] [G loss: 0.8918]
# [Epoch 38/50] [Batch 1500/1950] [D loss: 0.6539] [G loss: 0.8643]
# [Epoch 38/50] [Batch 1600/1950] [D loss: 0.6788] [G loss: 0.8789]
# [Epoch 38/50] [Batch 1700/1950] [D loss: 0.6609] [G loss: 0.8801]
# [Epoch 38/50] [Batch 1800/1950] [D loss: 0.6534] [G loss: 0.8272]
# [Epoch 38/50] [Batch 1900/1950] [D loss: 0.6436] [G loss: 0.8427]
# [Epoch 39/50] [Batch 0/1950] [D loss: 0.6645] [G loss: 0.8911]
# [Epoch 39/50] [Batch 100/1950] [D loss: 0.6346] [G loss: 0.8635]
# [Epoch 39/50] [Batch 200/1950] [D loss: 0.6826] [G loss: 0.9021]
# [Epoch 39/50] [Batch 300/1950] [D loss: 0.6485] [G loss: 0.8878]
# [Epoch 39/50] [Batch 400/1950] [D loss: 0.6447] [G loss: 0.8858]
# [Epoch 39/50] [Batch 500/1950] [D loss: 0.6789] [G loss: 0.8886]
# [Epoch 39/50] [Batch 600/1950] [D loss: 0.6759] [G loss: 0.8676]
# [Epoch 39/50] [Batch 700/1950] [D loss: 0.6509] [G loss: 0.8802]
# [Epoch 39/50] [Batch 800/1950] [D loss: 0.6606] [G loss: 0.8263]
# [Epoch 39/50] [Batch 900/1950] [D loss: 0.6496] [G loss: 0.8280]
# [Epoch 39/50] [Batch 1000/1950] [D loss: 0.6749] [G loss: 0.9281]
# [Epoch 39/50] [Batch 1100/1950] [D loss: 0.6731] [G loss: 0.8791]
# [Epoch 39/50] [Batch 1200/1950] [D loss: 0.6780] [G loss: 0.8459]
# [Epoch 39/50] [Batch 1300/1950] [D loss: 0.6512] [G loss: 0.9196]
# [Epoch 39/50] [Batch 1400/1950] [D loss: 0.6549] [G loss: 0.8729]
# [Epoch 39/50] [Batch 1500/1950] [D loss: 0.6478] [G loss: 0.8742]
# [Epoch 39/50] [Batch 1600/1950] [D loss: 0.6483] [G loss: 0.8454]
# [Epoch 39/50] [Batch 1700/1950] [D loss: 0.6635] [G loss: 0.8712]
# [Epoch 39/50] [Batch 1800/1950] [D loss: 0.6558] [G loss: 0.8870]
# [Epoch 39/50] [Batch 1900/1950] [D loss: 0.6781] [G loss: 0.8792]
# [Epoch 40/50] [Batch 0/1950] [D loss: 0.6932] [G loss: 0.8132]
# [Epoch 40/50] [Batch 100/1950] [D loss: 0.6526] [G loss: 0.8614]
# [Epoch 40/50] [Batch 200/1950] [D loss: 0.6593] [G loss: 0.8481]
# [Epoch 40/50] [Batch 300/1950] [D loss: 0.6591] [G loss: 0.8779]
# [Epoch 40/50] [Batch 400/1950] [D loss: 0.6517] [G loss: 0.9245]
# [Epoch 40/50] [Batch 500/1950] [D loss: 0.6612] [G loss: 0.8713]
# [Epoch 40/50] [Batch 600/1950] [D loss: 0.6878] [G loss: 0.8157]
# [Epoch 40/50] [Batch 700/1950] [D loss: 0.6755] [G loss: 0.8509]
# [Epoch 40/50] [Batch 800/1950] [D loss: 0.6822] [G loss: 0.8590]
# [Epoch 40/50] [Batch 900/1950] [D loss: 0.6620] [G loss: 0.9002]
# [Epoch 40/50] [Batch 1000/1950] [D loss: 0.6716] [G loss: 0.8681]
# [Epoch 40/50] [Batch 1100/1950] [D loss: 0.6633] [G loss: 0.9020]
# [Epoch 40/50] [Batch 1200/1950] [D loss: 0.6613] [G loss: 0.9181]
# [Epoch 40/50] [Batch 1300/1950] [D loss: 0.6637] [G loss: 0.8671]
# [Epoch 40/50] [Batch 1400/1950] [D loss: 0.6531] [G loss: 0.8611]
# [Epoch 40/50] [Batch 1500/1950] [D loss: 0.6538] [G loss: 0.8816]
# [Epoch 40/50] [Batch 1600/1950] [D loss: 0.6654] [G loss: 0.9011]
# [Epoch 40/50] [Batch 1700/1950] [D loss: 0.6497] [G loss: 0.8768]
# [Epoch 40/50] [Batch 1800/1950] [D loss: 0.6585] [G loss: 0.8750]
# [Epoch 40/50] [Batch 1900/1950] [D loss: 0.6801] [G loss: 0.9052]
# [Epoch 41/50] [Batch 0/1950] [D loss: 0.6526] [G loss: 0.9010]
# [Epoch 41/50] [Batch 100/1950] [D loss: 0.6537] [G loss: 0.8983]
# [Epoch 41/50] [Batch 200/1950] [D loss: 0.6671] [G loss: 0.8591]
# [Epoch 41/50] [Batch 300/1950] [D loss: 0.6617] [G loss: 0.8671]
# [Epoch 41/50] [Batch 400/1950] [D loss: 0.6702] [G loss: 0.8420]
# [Epoch 41/50] [Batch 500/1950] [D loss: 0.6719] [G loss: 0.8811]
# [Epoch 41/50] [Batch 600/1950] [D loss: 0.6619] [G loss: 0.8581]
# [Epoch 41/50] [Batch 700/1950] [D loss: 0.6631] [G loss: 0.8613]
# [Epoch 41/50] [Batch 800/1950] [D loss: 0.6494] [G loss: 0.8355]
# [Epoch 41/50] [Batch 900/1950] [D loss: 0.6787] [G loss: 0.8417]
# [Epoch 41/50] [Batch 1000/1950] [D loss: 0.6586] [G loss: 0.9448]
# [Epoch 41/50] [Batch 1100/1950] [D loss: 0.6877] [G loss: 0.8600]
# [Epoch 41/50] [Batch 1200/1950] [D loss: 0.6488] [G loss: 0.8744]
# [Epoch 41/50] [Batch 1300/1950] [D loss: 0.6726] [G loss: 0.8602]
# [Epoch 41/50] [Batch 1400/1950] [D loss: 0.6574] [G loss: 0.8811]
# [Epoch 41/50] [Batch 1500/1950] [D loss: 0.6654] [G loss: 0.8994]
# [Epoch 41/50] [Batch 1600/1950] [D loss: 0.6720] [G loss: 0.8880]
# [Epoch 41/50] [Batch 1700/1950] [D loss: 0.6536] [G loss: 0.9053]
# [Epoch 41/50] [Batch 1800/1950] [D loss: 0.6643] [G loss: 0.8504]
# [Epoch 41/50] [Batch 1900/1950] [D loss: 0.6657] [G loss: 0.8868]
# [Epoch 42/50] [Batch 0/1950] [D loss: 0.6785] [G loss: 0.8735]
# [Epoch 42/50] [Batch 100/1950] [D loss: 0.6866] [G loss: 0.9223]
# [Epoch 42/50] [Batch 200/1950] [D loss: 0.6878] [G loss: 0.8913]
# [Epoch 42/50] [Batch 300/1950] [D loss: 0.6486] [G loss: 0.9177]
# [Epoch 42/50] [Batch 400/1950] [D loss: 0.7041] [G loss: 0.8709]
# [Epoch 42/50] [Batch 500/1950] [D loss: 0.6665] [G loss: 0.9192]
# [Epoch 42/50] [Batch 600/1950] [D loss: 0.6416] [G loss: 0.8600]
# [Epoch 42/50] [Batch 700/1950] [D loss: 0.6499] [G loss: 0.8204]
# [Epoch 42/50] [Batch 800/1950] [D loss: 0.6747] [G loss: 0.8564]
# [Epoch 42/50] [Batch 900/1950] [D loss: 0.6677] [G loss: 0.8602]
# [Epoch 42/50] [Batch 1000/1950] [D loss: 0.6620] [G loss: 0.8936]
# [Epoch 42/50] [Batch 1100/1950] [D loss: 0.6697] [G loss: 0.8501]
# [Epoch 42/50] [Batch 1200/1950] [D loss: 0.6607] [G loss: 0.8745]
# [Epoch 42/50] [Batch 1300/1950] [D loss: 0.6606] [G loss: 0.8393]
# [Epoch 42/50] [Batch 1400/1950] [D loss: 0.6957] [G loss: 0.8637]
# [Epoch 42/50] [Batch 1500/1950] [D loss: 0.6789] [G loss: 0.8587]
# [Epoch 42/50] [Batch 1600/1950] [D loss: 0.6529] [G loss: 0.8763]
# [Epoch 42/50] [Batch 1700/1950] [D loss: 0.6826] [G loss: 0.8418]
# [Epoch 42/50] [Batch 1800/1950] [D loss: 0.6620] [G loss: 0.8717]
# [Epoch 42/50] [Batch 1900/1950] [D loss: 0.6521] [G loss: 0.8491]
# [Epoch 43/50] [Batch 0/1950] [D loss: 0.6598] [G loss: 0.8776]
# [Epoch 43/50] [Batch 100/1950] [D loss: 0.6587] [G loss: 0.8887]
# [Epoch 43/50] [Batch 200/1950] [D loss: 0.6697] [G loss: 0.8705]
# [Epoch 43/50] [Batch 300/1950] [D loss: 0.6704] [G loss: 0.8769]
# [Epoch 43/50] [Batch 400/1950] [D loss: 0.6494] [G loss: 0.8554]
# [Epoch 43/50] [Batch 500/1950] [D loss: 0.6465] [G loss: 0.8911]
# [Epoch 43/50] [Batch 600/1950] [D loss: 0.6629] [G loss: 0.8375]
# [Epoch 43/50] [Batch 700/1950] [D loss: 0.6743] [G loss: 0.9040]
# [Epoch 43/50] [Batch 800/1950] [D loss: 0.6697] [G loss: 0.8878]
# [Epoch 43/50] [Batch 900/1950] [D loss: 0.6609] [G loss: 0.8941]
# [Epoch 43/50] [Batch 1000/1950] [D loss: 0.6850] [G loss: 0.8063]
# [Epoch 43/50] [Batch 1100/1950] [D loss: 0.6784] [G loss: 0.8941]
# [Epoch 43/50] [Batch 1200/1950] [D loss: 0.6631] [G loss: 0.8918]
# [Epoch 43/50] [Batch 1300/1950] [D loss: 0.6742] [G loss: 0.8842]
# [Epoch 43/50] [Batch 1400/1950] [D loss: 0.6628] [G loss: 0.8352]
# [Epoch 43/50] [Batch 1500/1950] [D loss: 0.6589] [G loss: 0.8773]
# [Epoch 43/50] [Batch 1600/1950] [D loss: 0.6580] [G loss: 0.8530]
# [Epoch 43/50] [Batch 1700/1950] [D loss: 0.6628] [G loss: 0.8426]
# [Epoch 43/50] [Batch 1800/1950] [D loss: 0.6690] [G loss: 0.8127]
# [Epoch 43/50] [Batch 1900/1950] [D loss: 0.7000] [G loss: 0.8620]
# [Epoch 44/50] [Batch 0/1950] [D loss: 0.6626] [G loss: 0.9117]
# [Epoch 44/50] [Batch 100/1950] [D loss: 0.6765] [G loss: 0.8477]
# [Epoch 44/50] [Batch 200/1950] [D loss: 0.6609] [G loss: 0.9094]
# [Epoch 44/50] [Batch 300/1950] [D loss: 0.6490] [G loss: 0.8620]
# [Epoch 44/50] [Batch 400/1950] [D loss: 0.6790] [G loss: 0.8922]
# [Epoch 44/50] [Batch 500/1950] [D loss: 0.7032] [G loss: 0.8748]
# [Epoch 44/50] [Batch 600/1950] [D loss: 0.6780] [G loss: 0.8656]
# [Epoch 44/50] [Batch 700/1950] [D loss: 0.6789] [G loss: 0.9093]
# [Epoch 44/50] [Batch 800/1950] [D loss: 0.6989] [G loss: 0.8629]
# [Epoch 44/50] [Batch 900/1950] [D loss: 0.6339] [G loss: 0.8783]
# [Epoch 44/50] [Batch 1000/1950] [D loss: 0.6711] [G loss: 0.8490]
# [Epoch 44/50] [Batch 1100/1950] [D loss: 0.6515] [G loss: 0.8845]
# [Epoch 44/50] [Batch 1200/1950] [D loss: 0.6861] [G loss: 0.8275]
# [Epoch 44/50] [Batch 1300/1950] [D loss: 0.6761] [G loss: 0.9194]
# [Epoch 44/50] [Batch 1400/1950] [D loss: 0.6790] [G loss: 0.8723]
# [Epoch 44/50] [Batch 1500/1950] [D loss: 0.6838] [G loss: 0.8299]
# [Epoch 44/50] [Batch 1600/1950] [D loss: 0.6836] [G loss: 0.8941]
# [Epoch 44/50] [Batch 1700/1950] [D loss: 0.6585] [G loss: 0.8514]
# [Epoch 44/50] [Batch 1800/1950] [D loss: 0.6758] [G loss: 0.8605]
# [Epoch 44/50] [Batch 1900/1950] [D loss: 0.6779] [G loss: 0.9084]
# [Epoch 45/50] [Batch 0/1950] [D loss: 0.6885] [G loss: 0.8371]
# [Epoch 45/50] [Batch 100/1950] [D loss: 0.6621] [G loss: 0.8605]
# [Epoch 45/50] [Batch 200/1950] [D loss: 0.6580] [G loss: 0.8582]
# [Epoch 45/50] [Batch 300/1950] [D loss: 0.6499] [G loss: 0.9231]
# [Epoch 45/50] [Batch 400/1950] [D loss: 0.6708] [G loss: 0.8297]
# [Epoch 45/50] [Batch 500/1950] [D loss: 0.6499] [G loss: 0.8487]
# [Epoch 45/50] [Batch 600/1950] [D loss: 0.6583] [G loss: 0.8851]
# [Epoch 45/50] [Batch 700/1950] [D loss: 0.6571] [G loss: 0.8566]
# [Epoch 45/50] [Batch 800/1950] [D loss: 0.6391] [G loss: 0.8918]
# [Epoch 45/50] [Batch 900/1950] [D loss: 0.6555] [G loss: 0.8635]
# [Epoch 45/50] [Batch 1000/1950] [D loss: 0.6571] [G loss: 0.9284]
# [Epoch 45/50] [Batch 1100/1950] [D loss: 0.6671] [G loss: 0.8588]
# [Epoch 45/50] [Batch 1200/1950] [D loss: 0.6675] [G loss: 0.8593]
# [Epoch 45/50] [Batch 1300/1950] [D loss: 0.6619] [G loss: 0.8350]
# [Epoch 45/50] [Batch 1400/1950] [D loss: 0.6793] [G loss: 0.8473]
# [Epoch 45/50] [Batch 1500/1950] [D loss: 0.6844] [G loss: 0.8597]
# [Epoch 45/50] [Batch 1600/1950] [D loss: 0.6690] [G loss: 0.9257]
# [Epoch 45/50] [Batch 1700/1950] [D loss: 0.6505] [G loss: 0.8694]
# [Epoch 45/50] [Batch 1800/1950] [D loss: 0.6907] [G loss: 0.8691]
# [Epoch 45/50] [Batch 1900/1950] [D loss: 0.6760] [G loss: 0.8994]
# [Epoch 46/50] [Batch 0/1950] [D loss: 0.6453] [G loss: 0.8325]
# [Epoch 46/50] [Batch 100/1950] [D loss: 0.6735] [G loss: 0.8607]
# [Epoch 46/50] [Batch 200/1950] [D loss: 0.6808] [G loss: 0.8902]
# [Epoch 46/50] [Batch 300/1950] [D loss: 0.6712] [G loss: 0.9035]
# [Epoch 46/50] [Batch 400/1950] [D loss: 0.6945] [G loss: 0.8760]
# [Epoch 46/50] [Batch 500/1950] [D loss: 0.6570] [G loss: 0.8817]
# [Epoch 46/50] [Batch 600/1950] [D loss: 0.6822] [G loss: 0.8397]
# [Epoch 46/50] [Batch 700/1950] [D loss: 0.6444] [G loss: 0.7877]
# [Epoch 46/50] [Batch 800/1950] [D loss: 0.6376] [G loss: 0.8673]
# [Epoch 46/50] [Batch 900/1950] [D loss: 0.6656] [G loss: 0.8253]
# [Epoch 46/50] [Batch 1000/1950] [D loss: 0.6530] [G loss: 0.9251]
# [Epoch 46/50] [Batch 1100/1950] [D loss: 0.6801] [G loss: 0.8685]
# [Epoch 46/50] [Batch 1200/1950] [D loss: 0.6566] [G loss: 0.8794]
# [Epoch 46/50] [Batch 1300/1950] [D loss: 0.6773] [G loss: 0.9258]
# [Epoch 46/50] [Batch 1400/1950] [D loss: 0.6862] [G loss: 0.8688]
# [Epoch 46/50] [Batch 1500/1950] [D loss: 0.6659] [G loss: 0.8792]
# [Epoch 46/50] [Batch 1600/1950] [D loss: 0.6878] [G loss: 0.8898]
# [Epoch 46/50] [Batch 1700/1950] [D loss: 0.6519] [G loss: 0.8823]
# [Epoch 46/50] [Batch 1800/1950] [D loss: 0.6708] [G loss: 0.8563]
# [Epoch 46/50] [Batch 1900/1950] [D loss: 0.6472] [G loss: 0.8598]
# [Epoch 47/50] [Batch 0/1950] [D loss: 0.6641] [G loss: 0.8537]
# [Epoch 47/50] [Batch 100/1950] [D loss: 0.6727] [G loss: 0.8698]
# [Epoch 47/50] [Batch 200/1950] [D loss: 0.6521] [G loss: 0.8500]
# [Epoch 47/50] [Batch 300/1950] [D loss: 0.6493] [G loss: 0.8730]
# [Epoch 47/50] [Batch 400/1950] [D loss: 0.6986] [G loss: 0.8385]
# [Epoch 47/50] [Batch 500/1950] [D loss: 0.6784] [G loss: 0.8910]
# [Epoch 47/50] [Batch 600/1950] [D loss: 0.6663] [G loss: 0.9438]
# [Epoch 47/50] [Batch 700/1950] [D loss: 0.6665] [G loss: 0.8353]
# [Epoch 47/50] [Batch 800/1950] [D loss: 0.6619] [G loss: 0.8739]
# [Epoch 47/50] [Batch 900/1950] [D loss: 0.6765] [G loss: 0.8867]
# [Epoch 47/50] [Batch 1000/1950] [D loss: 0.6904] [G loss: 0.9131]
# [Epoch 47/50] [Batch 1100/1950] [D loss: 0.6762] [G loss: 0.8952]
# [Epoch 47/50] [Batch 1200/1950] [D loss: 0.6431] [G loss: 0.8348]
# [Epoch 47/50] [Batch 1300/1950] [D loss: 0.6695] [G loss: 0.8158]
# [Epoch 47/50] [Batch 1400/1950] [D loss: 0.6596] [G loss: 0.8222]
# [Epoch 47/50] [Batch 1500/1950] [D loss: 0.6485] [G loss: 0.8963]
# [Epoch 47/50] [Batch 1600/1950] [D loss: 0.6457] [G loss: 0.8653]
# [Epoch 47/50] [Batch 1700/1950] [D loss: 0.6548] [G loss: 0.8484]
# [Epoch 47/50] [Batch 1800/1950] [D loss: 0.6654] [G loss: 0.8747]
# [Epoch 47/50] [Batch 1900/1950] [D loss: 0.6750] [G loss: 0.8868]
# [Epoch 48/50] [Batch 0/1950] [D loss: 0.6737] [G loss: 0.8292]
# [Epoch 48/50] [Batch 100/1950] [D loss: 0.6746] [G loss: 0.8802]
# [Epoch 48/50] [Batch 200/1950] [D loss: 0.6822] [G loss: 0.8376]
# [Epoch 48/50] [Batch 300/1950] [D loss: 0.6501] [G loss: 0.8798]
# [Epoch 48/50] [Batch 400/1950] [D loss: 0.6505] [G loss: 0.8822]
# [Epoch 48/50] [Batch 500/1950] [D loss: 0.6829] [G loss: 0.9162]
# [Epoch 48/50] [Batch 600/1950] [D loss: 0.6583] [G loss: 0.9202]
# [Epoch 48/50] [Batch 700/1950] [D loss: 0.6876] [G loss: 0.8873]
# [Epoch 48/50] [Batch 800/1950] [D loss: 0.6449] [G loss: 0.8518]
# [Epoch 48/50] [Batch 900/1950] [D loss: 0.6685] [G loss: 0.8317]
# [Epoch 48/50] [Batch 1000/1950] [D loss: 0.6666] [G loss: 0.8594]
# [Epoch 48/50] [Batch 1100/1950] [D loss: 0.6807] [G loss: 0.9032]
# [Epoch 48/50] [Batch 1200/1950] [D loss: 0.6554] [G loss: 0.8917]
# [Epoch 48/50] [Batch 1300/1950] [D loss: 0.6818] [G loss: 0.8976]
# [Epoch 48/50] [Batch 1400/1950] [D loss: 0.6550] [G loss: 0.9042]
# [Epoch 48/50] [Batch 1500/1950] [D loss: 0.6638] [G loss: 0.8456]
# [Epoch 48/50] [Batch 1600/1950] [D loss: 0.6611] [G loss: 0.8481]
# [Epoch 48/50] [Batch 1700/1950] [D loss: 0.6467] [G loss: 0.8499]
# [Epoch 48/50] [Batch 1800/1950] [D loss: 0.6494] [G loss: 0.8557]
# [Epoch 48/50] [Batch 1900/1950] [D loss: 0.6646] [G loss: 0.8631]
# [Epoch 49/50] [Batch 0/1950] [D loss: 0.6466] [G loss: 0.8828]
# [Epoch 49/50] [Batch 100/1950] [D loss: 0.6737] [G loss: 0.8965]
# [Epoch 49/50] [Batch 200/1950] [D loss: 0.6740] [G loss: 0.8502]
# [Epoch 49/50] [Batch 300/1950] [D loss: 0.6812] [G loss: 0.9040]
# [Epoch 49/50] [Batch 400/1950] [D loss: 0.6676] [G loss: 0.8799]
# [Epoch 49/50] [Batch 500/1950] [D loss: 0.6754] [G loss: 0.8880]
# [Epoch 49/50] [Batch 600/1950] [D loss: 0.6479] [G loss: 0.8312]
# [Epoch 49/50] [Batch 700/1950] [D loss: 0.6372] [G loss: 0.8923]
# [Epoch 49/50] [Batch 800/1950] [D loss: 0.6607] [G loss: 0.8968]
# [Epoch 49/50] [Batch 900/1950] [D loss: 0.6764] [G loss: 0.8780]
# [Epoch 49/50] [Batch 1000/1950] [D loss: 0.7068] [G loss: 0.8767]
# [Epoch 49/50] [Batch 1100/1950] [D loss: 0.6363] [G loss: 0.9064]
# [Epoch 49/50] [Batch 1200/1950] [D loss: 0.6922] [G loss: 0.8647]
# [Epoch 49/50] [Batch 1300/1950] [D loss: 0.6549] [G loss: 0.9287]
# [Epoch 49/50] [Batch 1400/1950] [D loss: 0.6626] [G loss: 0.8276]
# [Epoch 49/50] [Batch 1500/1950] [D loss: 0.6581] [G loss: 0.8733]
# [Epoch 49/50] [Batch 1600/1950] [D loss: 0.6645] [G loss: 0.9138]
# [Epoch 49/50] [Batch 1700/1950] [D loss: 0.6727] [G loss: 0.8408]
# [Epoch 49/50] [Batch 1800/1950] [D loss: 0.6645] [G loss: 0.8523]
# [Epoch 49/50] [Batch 1900/1950] [D loss: 0.6647] [G loss: 0.8564]

# %% [markdown]
# ## 1.7 Visualizing training progress

# %%
# Plot the losses
plt.figure(figsize=(10, 5))
plt.title("Generator and Discriminator Loss During Training")
plt.plot(G_losses, label="Generator")
plt.plot(D_losses, label="Discriminator")
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# ## 1.8 Visualizing results

# %%
# Generate fake images with the trained generator
num_generate = 25  # Number of images to generate
z = torch.randn(num_generate, latent_dim, device=device)

with torch.no_grad():
    generator.eval()
    fake_imgs = generator(z).detach().cpu()

# Display the generated images
plt.figure(figsize=(10, 10))
plt.axis("off")
plt.title("Generated Images")
plt.imshow(
    np.transpose(
        vutils.make_grid(fake_imgs, padding=2, normalize=True).numpy(),
        (1, 2, 0)
    ),
    cmap='gray'
)
plt.show()

# %% [markdown]
# ## 1.9 Visualizing training progression

# %%
# Create a grid to show how generated images evolved during training
num_epochs_to_show = min(8, num_epochs)  # Show up to 8 epochs
selected_epochs = np.linspace(0, len(generated_images)-1, num_epochs_to_show, dtype=int)

fig = plt.figure(figsize=(12, 8))
plt.axis("off")
plt.title("Generator Training Progress")

for i, epoch_idx in enumerate(selected_epochs):
    epoch_images = generated_images[epoch_idx]
    grid = vutils.make_grid(epoch_images[:4], padding=2, normalize=True)
    ax = plt.subplot(2, num_epochs_to_show//2, i+1)
    ax.set_title(f"Epoch {epoch_idx}")
    ax.axis("off")
    ax.imshow(np.transpose(grid, (1, 2, 0)), cmap='gray')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 1.10 Model Saving

# %%
torch.save(generator.state_dict(), "models/emnist_gan_generator.pth")
torch.save(discriminator.state_dict(), "models/emnist_gan_discriminator.pth")
print("Models saved successfully!")
# Out:
# Models saved successfully!

# %% [markdown]
# ## 1.11 Evaluation

# %%
def generate_samples(model, latent_dim, num_samples=100, device=device):
    """Generate a specified number of samples from the trained generator"""
    # Create random noise vectors
    z = torch.randn(num_samples, latent_dim, device=device)
    
    # Generate images
    with torch.no_grad():
        model.eval()
        samples = model(z).detach().cpu()
    
    return samples

# %%
# Generate 100 samples
generated_samples = generate_samples(generator, latent_dim, num_samples=100)

# %%
# Display a subset of 35 samples
plt.figure(figsize=(10, 10))
plt.axis("off")
plt.title("Generated Samples for Evaluation")
plt.imshow(
    np.transpose(
        vutils.make_grid(generated_samples[:35], nrow=5, padding=2, normalize=True).numpy(),
        (1, 2, 0)
    ),
    cmap='gray'
)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## GAN Implementation for Handwritten Character Generation - Summary
#
# ### Project Overview
# This project implements a Generative Adversarial Network (GAN) to generate realistic handwritten characters using the EMNIST dataset. The implementation includes a complete GAN architecture with a generator and discriminator, training procedure, and evaluation methods.
#
# ### Key Components
#
# #### 1. Data Preparation
# - Successfully loaded the EMNIST dataset with letter classes
# - Applied appropriate transformations (normalization to [-1,1] range)
# - Created efficient data loaders with batch processing
#
# #### 2. GAN Architecture
#
# **Generator**
# - Implemented a deep convolutional generator
# - Takes random noise vectors (100-dimensional) as input
# - Uses upsampling and convolutional layers to generate 28×28 pixel images
# - Incorporates batch normalization and LeakyReLU activations for stable training
# - Final Tanh activation ensures output range matches normalized training data
#
# **Discriminator**
# - Implemented a convolutional discriminator with dynamically sized layers
# - Uses strided convolutions for downsampling
# - Includes dropout for regularization
# - Features a flexible architecture that adapts to the actual feature dimensions during runtime
# - Final sigmoid activation for binary classification (real vs. fake)
#
# #### 3. Training Process
# - Implemented alternating training of generator and discriminator
# - Applied label smoothing to stabilize training
# - Added noise to inputs and labels to prevent overfitting
# - Introduced dynamic learning rate scheduling
# - Successfully trained for 50 epochs
#
# #### 4. Improvements to Combat Mode Collapse
# Implemented several techniques to address the mode collapse problem:
# - Added noise to the latent space
# - Applied smoothing to labels
# - Included additional layers in both networks
# - Modified the architecture to encourage diversity
#
# #### 5. Results and Evaluation
# - Generated diverse handwritten characters that resemble the training data
# - Achieved stable loss curves for both generator and discriminator
# - Demonstrated progressive improvement in quality over training epochs
# - Successfully produced readable, realistic character forms
#
# ### Technical Achievements
# - Solved dimensional compatibility issues between convolutional and linear layers
# - Implemented robust error handling for training stability
# - Created visualization tools to monitor progress throughout training
# - Successfully addressed common GAN training challenges (mode collapse, training instability)
#
# ### Conclusion
# The implementation successfully demonstrates a working GAN for character generation. The final model produces diverse, recognizable handwritten characters that exhibit natural variations in style, stroke width, and orientation, similar to human handwriting. The training process was stable, with both networks converging to a balanced equilibrium.
